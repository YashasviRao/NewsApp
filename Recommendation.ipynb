# %% [markdown]
# # Recommendation

# %% [markdown]
# ## 1. Importing necessary Libraries

# %%
import numpy as np
import pandas as pd

import os
import math
import time
import json

import matplotlib.pyplot as plt
import seaborn as sns
import plotly.figure_factory as ff
import plotly.graph_objects as go
import plotly.express as px

# Libraries for text processing using NLTK
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# Libraries for feature representation using sklearn
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

# Libraries for similarity matrices using sklearn
from sklearn.metrics.pairwise import cosine_similarity  
from sklearn.metrics import pairwise_distances

# %% [markdown]
# ## 2. Loading Data

# %% [markdown]
# * Utilizing the drive module from google.colab to mount my Google Drive to Colab. After that, it enables me to explore the contents via “Files explorer” and read the data.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# * csv file consisting of the final dataframe from classification notebook is uploaded into google drive, then downloaded and read into a new dataframe in this Recommendation notebook using the following code.
# * Since classification is performed using two different algorithms, we have to csv files as output and hence two new dataframes namely : kmeansDf and nmfDf are utilised.

# %%
! gdown 1PvwhRnfzh9xSDEB2tMTXF_NarbuWLFQN
path_dir = '/content/'
kmeansDf_path = path_dir + 'classification(KMeans).csv'
kmeansDf= pd.read_csv(kmeansDf_path)

! gdown 1WLfIEhBEvpVhF2pTLCssolWSBMcIdzNv
path_dir = '/content/'
nmfDf_path = path_dir + 'classification(NMF).csv'
# nmfDf= pd.read_csv(nmfDf_path)
news_articles=pd.read_csv(nmfDf_path)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1PvwhRnfzh9xSDEB2tMTXF_NarbuWLFQN
# To: /content/classification(KMeans).csv
# 100% 54.4k/54.4k [00:00<00:00, 33.9MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1WLfIEhBEvpVhF2pTLCssolWSBMcIdzNv
# To: /content/classification(NMF).csv
# 100% 198k/198k [00:00<00:00, 55.8MB/s]

# %%
print(len(news_articles))
# Out:
# 64

# %% [markdown]
# The recommendations for an article are going to be from the set of articles that are available in the news_articles variable.

# %% [markdown]
# ## 3. Data Preprocessing

# %%
news_articles.shape
# Out:
# (64, 11)

# %% [markdown]
# Now, the number of news articles that are currently available from the nbc news's website are 64

# %% [markdown]
# ### 3.a Removing all the short headline articles

# %% [markdown]
# After stop words removal from headline, the articles with very short headline may become blank headline articles. So let's remove all the articles with less words(<5) in the headline.

# %%
news_articles = news_articles[news_articles['headline'].apply(lambda x: len(x.split())>5)]
print("Total number of articles after removal of headlines with short title:", news_articles.shape[0])
# Out:
# Total number of articles after removal of headlines with short title: 63

# %% [markdown]
# ### 3.b Checking and removing all the duplicates

# %% [markdown]
# Since some articles are exactly same in headlines, so let's remove all such articles having duplicate headline appearance.

# %%
news_articles.sort_values('headline',inplace=True, ascending=False)
duplicated_articles_series = news_articles.duplicated('headline', keep = False)
news_articles = news_articles[~duplicated_articles_series]
print("Total number of articles after removing duplicates:", news_articles.shape[0])
# Out:
# Total number of articles after removing duplicates: 63

# %% [markdown]
# ### 3.c Checking for missing values

# %%
news_articles.isna().sum()
# Out:
# Unnamed: 0      0
# id              0
# headline        0
# summary         0
# category        0
# suggestions     0
# img             0
# no_punct        0
# no_punct_num    0
# no_stopwords    0
# clean_text      0
# dtype: int64

# %% [markdown]
# ## 4. Basic Data Exploration

# %% [markdown]
# ### 4.a Basic statistics - Number of articles,authors,categories

# %%
print("Total number of articles : ", news_articles.shape[0])
print("Total number of unqiue categories : ", news_articles["category"].nunique())
# Out:
# Total number of articles :  63
# Total number of unqiue categories :  5

# %% [markdown]
# ### 4.b Distribution of articles category-wise

# %%
fig = go.Figure([go.Bar(x=news_articles["category"].value_counts().index, y=news_articles["category"].value_counts().values)])
fig['layout'].update(title={"text" : 'Distribution of articles category-wise','y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'}, xaxis_title="Category name",yaxis_title="Number of articles")
fig.update_layout(width=800,height=700)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6302177b-610b-4043-b800-19f76a38e7fa" class="plotly-graph-div" style="height:700px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6302177b-610b-4043-b800-19f76a38e7fa")) {                    Plotly.newPlot(                        "6302177b-610b-4043-b800-19f76a38e7fa",                        [{"x":["politics","tech","business","entertainment","sport"],"y":[24,14,14,10,1],"type":"bar"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scattercarpet"}],"scattergeo":[{"marker":{"colorbar":{"outlinewidth" ...

# %% [markdown]
# From the bar chart, we can observe that **politics** category has **highest** number of articles then **entertainment** and so on.

# %% [markdown]
# 4.c PDF for the length of headlines

# %%
fig = ff.create_distplot([news_articles['headline'].str.len()], ["ht"],show_hist=False,show_rug=False)
fig['layout'].update(title={'text':'PDF','y':0.9,'x':0.5,'xanchor': 'center','yanchor': 'top'}, xaxis_title="Length of a headline",yaxis_title="probability")
fig.update_layout(showlegend = False,width=500,height=500)
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ffdec592-1d5b-47f9-994e-4d0268270e0a" class="plotly-graph-div" style="height:500px; width:500px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ffdec592-1d5b-47f9-994e-4d0268270e0a")) {                    Plotly.newPlot(                        "ffdec592-1d5b-47f9-994e-4d0268270e0a",                        [{"legendgroup":"ht","marker":{"color":"rgb(31, 119, 180)"},"mode":"lines","name":"ht","showlegend":true,"x":[45.0,45.156,45.312,45.468,45.624,45.78,45.936,46.092,46.248,46.403999999999996,46.56,46.716,46.872,47.028,47.184,47.34,47.496,47.652,47.808,47.964,48.12,48.275999999999996,48.432,48.588,48.744,48.9,49.056,49.212,49.368,49.524,49.68,49.836,49.992,50.147999999999996,50.304,50.46,50.616,50.772,50.928,51.084,51.24,51.396,51.552,51.708,51.864,52.019999999999996,52.176,52.332,52.488,52.644,52.8,52.956,53.112,53.268,53.424,53.58,53.736000000000004,53.891999999999996,54.048,54.204,54.36,54.516,54.672,54.828,54.984,55.14,55.296,55.452,55.608000000000004,55.763999999999996,55.92,56.076,56.232,56.388,56.544,56.7,56.856,57.012,57.168,57.324,57.480000000000004,57.635999999999996,57.792,57.948,58.104,58.26,58.416,58.572,58.728,58.884,59.04,59.196,59.352000000000004,59.507999999999996,59.664,59.82,59.976,60.132,60.288,60.444,60.6,60.756,60.912,61.068,61.224000000000004,61.379999999999995,61.536,61.692,61.848,62.004000000000005,62.16,62.316,62.472,62.628,62.784,62.94,63.096000000000004,63.251999999999995,63.408,63.564,63.72,63.876000000000005,64.032,64.188,64.344,64.5,64.656,64.812,64.968,65.124,65.28,65.436,65.592,65.748,65.904,66.06,66.21600000000001,66.372,66.52799999999999,66.684,66.84,66.996,67.152,67.30799999999999,67.464,67.62,67.776,67.932,68.088,68.244,68.4,68.556,68.712,68.868,69.024,69.18,69.336,69.492,69.648,69.804,69.96000000000001,70.116,70.27199999999999,70.428,70.584,70.74,70.896,71.05199999999999,71.208,71.364,71.52,71.676,71.832,71.988,72.144,72.3,72.456,72.612,72.768,72.924,73.08,73.236,73.392,73.548,73.70400000000001,73.86,74.01599999999999,74.172,74.328,74.48400000000001,74.64,74.79599999999999,74.952,75.108,75.264,75.42,75.576,75.732,75.888,76.044,76.2,76.356,76.512,76.668,76.824,76.98,77.136,77.292,77.44800000000001,77.604,77.75999999999999,77.916,78.072,78.22800000000001,78.384,78.53999999999999,78.696,78.852,79.00800000000001,79.164,79.32,79.476,79.632,79.788,79.944,80.1,80.256,80.412,80.568,80.72399999999999,80.88,81.036,81.19200000000001,81.348,81.50399999999999,81.66,81.816,81.97200000000001,82.128,82.28399999999999,82.44,82.596,82.75200000000001,82.908,83.064,83.22,83.376,83.532,83.688,83.844,84.0,84.156,84.312,84.468,84.624,84.78,84.936,85.092,85.24799999999999,85.404,85.56,85.71600000000001,85.872,86.02799999999999,86.184,86.34,86.49600000000001,86.652,86.80799999999999,86.964,87.12,87.27600000000001,87.432,87.588,87.744,87.9,88.056,88.212,88.368,88.524,88.68,88.836,88.99199999999999,89.148,89.304,89.46000000000001,89.616,89.77199999999999,89.928,90.084,90.24000000000001,90.396,90.55199999999999,90.708,90.864,91.02000000000001,91.176,91.332,91.488,91.644,91.8,91.956,92.112,92.268,92.424,92.58,92.73599999999999,92.892,93.048,93.20400000000001,93.36,93.51599999999999,93.672,93.828,93.98400000000001,94.14,94.29599999999999,94.452,94.608,94.76400000000001,94.92,95.076,95.232,95.388,95.544,95.7,95.856,96.012,96.168,96.324,96.47999999999999,96.636,96.792,96.94800000000001,97.104,97.25999999999999,97.416,97.572,97.72800000000001,97.884,98.03999999999999,98.196,98.352,98.50800000000001,98.664,98.82,98.976,99.132,99.288,99.444,99.6,99.756,99.912,100.068,100.22399999999999,100.38,100.536,100.69200000000001,100.848,101.00399999999999,101.16,101.316,101.47200000000001,101.628,101.78399999999999,101.94,102.096,102.25200000000001,102.408,102.564,102.72,102.876,103.032,103.188,103.3 ...

# %% [markdown]
# The probability distribution function of headline length is almost similar to a **Guassian distribution**, where most of the headlines are 58 to 80 words long in length.

# %% [markdown]
# By Data processing in Step 2, we get a subset of original dataset which has different index labels so let's make the indices uniform ranging from 0 to total number of articles.

# %%
news_articles.index = range(news_articles.shape[0])

# %%
news_articles_temp = news_articles.copy()

# %% [markdown]
# ## 5. Text Preprocessing

# %% [markdown]
# ### 5.a Stopwords removal

# %% [markdown]
# Stop words are not much helpful in analyis and also their inclusion consumes much time during processing so let's remove these.

# %%
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package omw-1.4 to /root/nltk_data...
# True

# %%
stop_words = set(stopwords.words('english'))

# %%
for i in range(len(news_articles_temp["headline"])):
    string = ""
    for word in news_articles_temp["headline"][i].split():
        word = ("".join(e for e in word if e.isalnum()))
        word = word.lower()
        if not word in stop_words:
          string += word + " "  
    if(i%1000==0):
      print(i)           # To track number of records processed
    news_articles_temp.at[i,"headline"] = string.strip()
# Out:
# 0

# %% [markdown]
# ### 5.b Lemmatization

# %% [markdown]
# Let's find the base form(lemma) of words to consider different inflections of a word same as lemma.

# %%
lemmatizer = WordNetLemmatizer()

# %%
for i in range(len(news_articles_temp["headline"])):
    string = ""
    for w in word_tokenize(news_articles_temp["headline"][i]):
        string += lemmatizer.lemmatize(w,pos = "v") + " "
    news_articles_temp.at[i, "headline"] = string.strip()
    if(i%1000==0):
        print(i)           # To track number of records processed
# Out:
# 0

# %% [markdown]
# ## 6. Headline based similarity on new articles

# %% [markdown]
# Generally, we assess **similarity** based on **distance**. If the **distance** is minimum then high **similarity** and if it is maximum then low **similarity**.
# To calculate the **distance**, we need to represent the headline as a **d-dimensional** vector. Then we can find out the **similarity** based on the **distance** between vectors.
#
# There are multiple methods to represent a **text** as **d-dimensional** vector like **Bag of words**, **TF-IDF method**, **Word2Vec embedding** etc. Each method has its own advantages and disadvantages.
#
# Let's see the feature representation of headline through all the methods one by one.

# %% [markdown]
# Creating dataframes for each method that is being used. All these dataframes are used to provide a good comarision of the impact of different models on the same data.

# %%
path_dir = '/content/'
path = path_dir + 'classification(NMF).csv'
df_bow=pd.read_csv(path)
df_tfidf=pd.read_csv(path)
df_w2v=pd.read_csv(path)
df_onehot=pd.read_csv(path)

# %% [markdown]
# ### 6.a Using Bag of Words method

# %% [markdown]
# A **Bag of Words(BoW)** method represents the occurence of words within a **document**. Here, each headline can be considered as a **document** and set of all headlines form a **corpus**.
#
# Using **BoW** approach, each **document** is represented by a **d-dimensional** vector, where **d** is total number of **unique words** in the corpus. The set of such unique words forms the **Vocabulary**.

# %%
headline_vectorizer = CountVectorizer()
headline_features   = headline_vectorizer.fit_transform(news_articles_temp['headline'])

# %%
headline_features.get_shape()
# Out:
# (63, 494)

# %% [markdown]
# The output **BoW matrix**(headline_features) is a sparse matrix.

# %%
pd.set_option('display.max_colwidth', -1)  # To display a very long headline completely
# Out:
# <ipython-input-22-bc6d054540ec>:1: FutureWarning:
#
# Passing a negative integer is deprecated in version 1.0 and will not be supported in future version. Instead, use None to not limit the column width.

# %%
def bag_of_words_based_model(row_index, num_similar_items):
    couple_dist = pairwise_distances(headline_features,headline_features[row_index])
    indices = np.argsort(couple_dist.ravel())[0:num_similar_items]
    df_bow.at[row_index,'suggestions']=indices
    dataFrame = pd.DataFrame({'headline':news_articles_temp['headline'][indices],'Euclidean similarity with the queried article': couple_dist[indices].ravel()})
    print("="*30,"Queried article details","="*30)
    print('headline : ',news_articles_temp['headline'][indices[0]])
    print("\n","="*25,"Recommended articles : ","="*23)
    return dataFrame.iloc[1:,]

for i in range(len(news_articles_temp)):
  print(bag_of_words_based_model(i, 4))
# Out:
# ============================== Queried article details ==============================
# headline :  workers consumers say theyre likely favor prolgbtq businesses study find
#
#  ========================= Recommended articles :  =======================
#                                               headline  \
# 61  2 boaters dog find safe strand sea
# 6   twitter disband trust safety council
# 38  tár dispel toxic lesbian stereotype find many film
#
#     Euclidean similarity with the queried article
# 61  3.741657
# 6   3.872983
# 38  4.000000
# ============================== Queried article details ==============================
# headline :  win ukraine could hinge side secure enough artillery ammunition
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 61  3.872983
# 2   3.872983
# ============================== Queried article details ==============================
# headline :  ignition fusion breakthrough draw energy gain
#
#  ========================= Recommended articles :  =======================
#                                           headline  \
# 6   twitter disband trust safety council
# 36  dangerous flu know symptoms sign complications
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   3.316625
# 36  3.464102
# 61  3.464102
# ============================== Queried article details ==============================
# headline :  virginias open congressional seat offer opportunity new generation black leaders
#
#  ========================= Recommended articles :  =======================
#                                             headline  \
# 12  biggest problem harry meghans new netflix series
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 12  3.872983
# 6   3.872983
# 61  4.000000
# ============================== Queried article details ==============================
# headline :  us set approve send patriot missile battery ukraine
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.605551
# 61  3.741657
# 2   3.741657
# ============================== Queried article details ==============================
# headline :  us postal service announce stamp honor late rep john lewis
#
#  ========================= Recommended articles :  =======================
#                                               headline  \
# 6  twitter disband trust safety council
# 2  ignition fusion breakthrough draw energy gain
# 4  us set approve send patriot missile battery ukraine
#
#    Euclidean similarity with the queried article
# 6  3.872983
# 2  4.000000
# 4  4.000000
# ============================== Queried article details ==============================
# headline :  twitter disband trust safety council
#
#  ========================= Recommended articles :  =======================
#                                           headline  \
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
# 36  dangerous flu know symptoms sign complications
#
#     Euclidean similarity with the queried article
# 61  3.316625
# 2   3.316625
# 36  3.316625
# ============================== Queried article details ==============================
# headline :  twitch call allow users create charity campaign nonprofits consider controversial
#
#  ========================= Recommended articles :  =======================
#                                                           headline  \
# 6   twitter disband trust safety council
# 17  samuel bankmanfried accuse make illegal campaign contributions
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   3.872983
# 17  3.872983
# 61  4.000000
# ============================== Queried article details ==============================
# headline :  travel coast coast samesex couple balance act
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 61  3.872983
# 2   3.872983
# ============================== Queried article details ==============================
# headline :  tornadoes tear swaths north texas southern oklahoma
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.464102
# 61  3.605551
# 2   3.605551
# ============================== Queried article details ==============================
# headline :  tina turners son ronnie die colon cancer complications medical examiner say
#
#  ========================= Recommended articles :  =======================
#                                                                   headline  \
# 36  dangerous flu know symptoms sign complications
# 6   twitter disband trust safety council
# 28  moderna say personalize mrna cancer vaccine effective advance melanoma
#
#     Euclidean similarity with the queried article
# 36  3.872983
# 6   4.000000
# 28  4.000000
# ============================== Queried article details ==============================
# headline :  ticketmaster mexico face millions fin bad bunny concert ticket screwup
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.872983
# 61  4.000000
# 2   4.000000
# ============================== Queried article details ==============================
# headline :  biggest problem harry meghans new netflix series
#
#  ========================= Recommended articles :  =======================
#                                           headline  \
# 6   twitter disband trust safety council
# 2   ignition fusion breakthrough draw energy gain
# 36  dangerous flu know symptoms sign complications
#
#     Euclidean similarity with the queried article
# 6   3.464102
# 2   3.605551
# 36  3.605551
# ============================== Queried article details ==============================
# headline :  taunt black student fight back civil right complaint say 30second fight derail life
#
#  ========================= Recommended articles :  =======================
#                                                         headline  \
# 6   twitter disband trust safety council
# 31  mcconnell say trump fuel candidate quality problems midterms
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   4.472136
# 31  4.582576
# 61  4.582576
# ============================== Queried article details ==============================
# headline :  student loan borrowers think get relief court put live hold
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.872983
# 61  4.000000
# 2   4.000000
# ============================== Queried article details ==============================
# headline :  state abortion restrictions higher maternal infant mortality report find
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 61  2 boaters dog find safe strand sea
# 6   twitter disband trust safety council
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 61  3.605551
# 6   3.741657
# 2   3.872983
# ============================== Queried article details ==============================
# headline :  scientists declare mauna loa kilauea longer erupt
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.464102
# 61  3.605551
# 2   3.605551
# ============================== Queried article details ==============================
# headline :  samuel bankmanfried accuse make illegal campaign contributions
#
#  ========================= Recommended articles :  =======================
#                                           headline  \
# 6   twitter disband trust safety council
# 36  dangerous flu know symptoms sign complications
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   3.464102
# 36  3.605551
# 61  3.605551
# ============================== Queried article details ==============================
# headline :  ron desantis outflank trump right call covid vaccine probe
#
#  ========================= Recommended articles :  =======================
#                                                         headline  \
# 6   twitter disband trust safety council
# 31  mcconnell say trump fuel candidate quality problems midterms
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 31  3.872983
# 61  3.872983
# ============================== Queried article details ==============================
# headline :  research find negative effect screen time kid include higher risk ocd
#
#  ========================= Recommended articles :  =======================
#                                                                     headline  \
# 61  2 boaters dog find safe strand sea
# 6   twitter disband trust safety council
# 15  state abortion restrictions higher maternal infant mortality report find
#
#     Euclidean similarity with the queried article
# 61  3.872983
# 6   4.000000
# 15  4.000000
# ============================== Queried article details ==============================
# headline :  puerto ricos shoreline change hurricane maria heighten coastal flood risk residents
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 2   ignition fusion breakthrough draw energy gain
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   4.000000
# 2   4.123106
# 61  4.123106
# ============================== Queried article details ==============================
# headline :  protesters block construction arizona border wall make ship containers
#
#  ========================= Recommended articles :  =======================
#                                                           headline  \
# 6   twitter disband trust safety council
# 17  samuel bankmanfried accuse make illegal campaign contributions
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 17  3.741657
# 61  3.872983
# ============================== Queried article details ==============================
# headline :  pope francis sympathize migrant caravan seek freedom wellbeing
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.605551
# 61  3.741657
# 2   3.741657
# ============================== Queried article details ==============================
# headline :  park land monuments deep latino root need protection report say
#
#  ========================= Recommended articles :  =======================
#                                           headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 36  dangerous flu know symptoms sign complications
#
#     Euclidean similarity with the queried article
# 6   3.872983
# 61  4.000000
# 36  4.000000
# ============================== Queried article details ==============================
# headline :  pot debilitate heart condition link covid lesser degree vaccines
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 61  3.872983
# 2   3.872983
# ============================== Queried article details ==============================
# headline :  oregon gov kate brown commute sentence 17 people death row
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.872983
# 61  4.000000
# 2   4.000000
# ============================== Queried article details ==============================
# headline :  next year good time buy ev many consumers 2024 might better
#
#  ========================= Recommended articles :  =======================
#                                               headline  \
# 6   twitter disband trust safety council
# 38  tár dispel toxic lesbian stereotype find many film
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   4.000000
# 38  4.123106
# 2   4.123106
# ============================== Queried article details ==============================
# headline :  myocarditis covid vaccine low among teens young adults large study find
#
#  ========================= Recommended articles :  =======================
#                                                       headline  \
# 61  2 boaters dog find safe strand sea
# 6   twitter disband trust safety council
# 18  ron desantis outflank trump right call covid vaccine probe
#
#     Euclidean similarity with the queried article
# 61  3.872983
# 6   4.000000
# 18  4.000000
# ============================== Queried article details ==============================
# headline :  moderna say personalize mrna cancer vaccine effective advance melanoma
#
#  ========================= Recommended articles :  =======================
#                                           headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 36  dangerous flu know symptoms sign complications
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 61  3.872983
# 36  3.872983
# ============================== Queried article details ==============================
# headline :  michelle yeoh join cast jon chus wicked film
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.605551
# 61  3.741657
# 2   3.741657
# ============================== Queried article details ==============================
# headline :  megan thee stallion tell court tory lanez shoot feet
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 61  3.872983
# 2   3.872983
# ============================== Queried article details ==============================
# headline :  mcconnell say trump fuel candidate quality problems midterms
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 2   ignition fusion breakthrough draw energy gain
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   3.605551
# 2   3.741657
# 61  3.741657
# ============================== Queried article details ==============================
# headline :  lawmakers unveil bipartisan bill ban tiktok nationwide
#
#  ========================= Recommended articles :  =======================
#                                                                     headline  \
# 6   twitter disband trust safety council
# 52  congressional negotiators reach bipartisan agreement framework fund deal
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   3.464102
# 52  3.605551
# 61  3.605551
# ============================== Queried article details ==============================
# headline :  jay leno get face full gas catch fire work garage
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.872983
# 61  4.000000
# 2   4.000000
# ============================== Queried article details ==============================
# headline :  inflation slow 71 november another sign economy cool
#
#  ========================= Recommended articles :  =======================
#                                           headline  \
# 36  dangerous flu know symptoms sign complications
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 36  3.464102
# 6   3.605551
# 61  3.741657
# ============================== Queried article details ==============================
# headline :  deny f22 sales ally lead ukjapanitaly stealth plane project
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 61  3.872983
# 2   3.872983
# ============================== Queried article details ==============================
# headline :  dangerous flu know symptoms sign complications
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.316625
# 61  3.464102
# 2   3.464102
# ============================== Queried article details ==============================
# headline :  dutch farmers become center global rightwing culture war
#
#  ========================= Recommended articles :  =======================
#                                           headline  \
# 6   twitter disband trust safety council
# 2   ignition fusion breakthrough draw energy gain
# 36  dangerous flu know symptoms sign complications
#
#     Euclidean similarity with the queried article
# 6   3.605551
# 2   3.741657
# 36  3.741657
# ============================== Queried article details ==============================
# headline :  tár dispel toxic lesbian stereotype find many film
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 61  2 boaters dog find safe strand sea
# 6   twitter disband trust safety council
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 61  3.464102
# 6   3.605551
# 2   3.741657
# ============================== Queried article details ==============================
# headline :  house gops inclusion salacious commanders cheerleaders photos official memo draw blowback
#
#  ========================= Recommended articles :  =======================
#                                                              headline  \
# 2   ignition fusion breakthrough draw energy gain
# 6   twitter disband trust safety council
# 41  historymaking nonbinary government official job theft accusations
#
#     Euclidean similarity with the queried article
# 2   3.872983
# 6   4.000000
# 41  4.000000
# ============================== Queried article details ==============================
# headline :  hotel employees comedian mark curry accuse racial profile suspend notice
#
#  ========================= Recommended articles :  =======================
#                                                           headline  \
# 6   twitter disband trust safety council
# 17  samuel bankmanfried accuse make illegal campaign contributions
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.872983
# 17  3.872983
# 2   4.000000
# ============================== Queried article details ==============================
# headline :  historymaking nonbinary government official job theft accusations
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 2   ignition fusion breakthrough draw energy gain
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   3.464102
# 2   3.605551
# 61  3.605551
# ============================== Queried article details ==============================
# headline :  heres social security check feature massive 2023 cola increase start arrive
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   4.000000
# 61  4.123106
# 2   4.123106
# ============================== Queried article details ==============================
# headline :  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   4.358899
# 61  4.472136
# 2   4.472136
# ============================== Queried article details ==============================
# headline :  black families phoenix child welfare investigations constant threat
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.605551
# 61  3.741657
# 2   3.741657
# ============================== Queried article details ==============================
# headline :  federal prisons suppose provide addiction medication prisoners punish use
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 61  3.872983
# 2   3.872983
# ============================== Queried article details ==============================
# headline :  facebook hit 2 billion lawsuit connect political violence africa
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.605551
# 61  3.741657
# 2   3.741657
# ============================== Queried article details ==============================
# headline :  elon musk astronaut scott kelly spar twitter pronoun use
#
#  ========================= Recommended articles :  =======================
#                                                       headline  \
# 6   twitter disband trust safety council
# 49  elon musk doesnt care pronouns unless nonbinary people use
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.464102
# 49  3.464102
# 2   3.872983
# ============================== Queried article details ==============================
# headline :  elon musk say stop child exploitation twitter far hes ax job push watchdogs
#
#  ========================= Recommended articles :  =======================
#                                                              headline  \
# 47  elon musk astronaut scott kelly spar twitter pronoun use
# 6   twitter disband trust safety council
# 41  historymaking nonbinary government official job theft accusations
#
#     Euclidean similarity with the queried article
# 47  4.000000
# 6   4.000000
# 41  4.242641
# ============================== Queried article details ==============================
# headline :  elon musk doesnt care pronouns unless nonbinary people use
#
#  ========================= Recommended articles :  =======================
#                                                              headline  \
# 47  elon musk astronaut scott kelly spar twitter pronoun use
# 41  historymaking nonbinary government official job theft accusations
# 6   twitter disband trust safety council
#
#     Euclidean similarity with the queried article
# 47  3.464102
# 41  3.741657
# 6   3.741657
# ============================== Queried article details ==============================
# headline :  donors meet paris get ukraine winter russian bomb
#
#  ========================= Recommended articles :  =======================
#                                           headline  \
# 6   twitter disband trust safety council
# 36  dangerous flu know symptoms sign complications
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.605551
# 36  3.741657
# 2   3.741657
# ============================== Queried article details ==============================
# headline :  disgrace ftx ceo sam bankmanfried orchestrate yearslong fraud investors customers sec criminal charge say
#
#  ========================= Recommended articles :  =======================
#                                                           headline  \
# 6   twitter disband trust safety council
# 17  samuel bankmanfried accuse make illegal campaign contributions
# 31  mcconnell say trump fuel candidate quality problems midterms
#
#     Euclidean similarity with the queried article
# 6   4.358899
# 17  4.358899
# 31  4.472136
# ============================== Queried article details ==============================
# headline :  congressional negotiators reach bipartisan agreement framework fund deal
#
#  ========================= Recommended articles :  =======================
#                                                   headline  \
# 32  lawmakers unveil bipartisan bill ban tiktok nationwide
# 6   twitter disband trust safety council
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 32  3.605551
# 6   3.605551
# 2   3.741657
# ============================== Queried article details ==============================
# headline :  blacklist russian propagandists thrive rightwing apps gab truth social study find
#
#  ========================= Recommended articles :  =======================
#                                                                     headline  \
# 61  2 boaters dog find safe strand sea
# 6   twitter disband trust safety council
# 0   workers consumers say theyre likely favor prolgbtq businesses study find
#
#     Euclidean similarity with the queried article
# 61  3.872983
# 6   4.000000
# 0   4.123106
# ============================== Queried article details ==============================
# headline :  black women play critical role help free brittney griner
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 61  3.872983
# 2   3.872983
# ============================== Queried article details ==============================
# headline :  biden sign samesex marriage bill white house ceremony
#
#  ========================= Recommended articles :  =======================
#                                                   headline  \
# 36  dangerous flu know symptoms sign complications
# 32  lawmakers unveil bipartisan bill ban tiktok nationwide
# 6   twitter disband trust safety council
#
#     Euclidean similarity with the queried article
# 36  3.464102
# 32  3.605551
# 6   3.605551
# ============================== Queried article details ==============================
# headline :  biden admin may cut number migrants eligible asylum border open new paths others
#
#  ========================= Recommended articles :  =======================
#                                             headline  \
# 6   twitter disband trust safety council
# 12  biggest problem harry meghans new netflix series
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   4.242641
# 12  4.242641
# 61  4.358899
# ============================== Queried article details ==============================
# headline :  asian americans heavily favor warnock georgia runoff exit poll show
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 2   ignition fusion breakthrough draw energy gain
# 61  2 boaters dog find safe strand sea
#
#     Euclidean similarity with the queried article
# 6   3.872983
# 2   4.000000
# 61  4.000000
# ============================== Queried article details ==============================
# headline :  ancient coin unearth desert cave could point evidence maccabean revolt
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 6   twitter disband trust safety council
# 61  2 boaters dog find safe strand sea
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.872983
# 61  4.000000
# 2   4.000000
# ============================== Queried article details ==============================
# headline :  amy schumer feel like new person operations treat endometriosis
#
#  ========================= Recommended articles :  =======================
#                                             headline  \
# 6   twitter disband trust safety council
# 12  biggest problem harry meghans new netflix series
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 12  3.741657
# 2   3.872983
# ============================== Queried article details ==============================
# headline :  new annual ritual debate whether retouch family holiday photo
#
#  ========================= Recommended articles :  =======================
#                                             headline  \
# 6   twitter disband trust safety council
# 12  biggest problem harry meghans new netflix series
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.741657
# 12  3.741657
# 2   3.872983
# ============================== Queried article details ==============================
# headline :  2 boaters dog find safe strand sea
#
#  ========================= Recommended articles :  =======================
#                                               headline  \
# 6   twitter disband trust safety council
# 38  tár dispel toxic lesbian stereotype find many film
# 2   ignition fusion breakthrough draw energy gain
#
#     Euclidean similarity with the queried article
# 6   3.316625
# 38  3.464102
# 2   3.464102
# ============================== Queried article details ==============================
# headline :  firmageddon researchers find 11 million acres dead tree oregon
#
#  ========================= Recommended articles :  =======================
#                                           headline  \
# 61  2 boaters dog find safe strand sea
# 6   twitter disband trust safety council
# 36  dangerous flu know symptoms sign complications
#
#     Euclidean similarity with the queried article
# 61  3.605551
# 6   3.741657
# 36  3.872983

# %%
df_bow.to_csv('df_bow.csv',index=False)

# %% [markdown]
# Above function recommends **4 similar** articles to the **queried**(read) article based on the headline. It accepts two arguments - index of already read artile and the total number of articles to be recommended.
#
# Based on the **Euclidean distance** it finds out 10 nearest neighbors and recommends.
#
# **Disadvantages**
# 1. It gives very low **importance** to less frequently observed words in the corpus. Few words from the queried article like "employer", "flip", "fire" appear less frequently in the entire corpus so **BoW** method does not recommend any article whose headline contains these words. Since **trump** is commonly observed word in the corpus so it is recommending the articles with headline containing "trump".
# 2. **BoW** method doesn't preserve the order of words.
#
# To overcome the first disadvantage we use **TF-IDF** method for feature representation.

# %% [markdown]
# ### 6.b Using TF-IDF method

# %% [markdown]
# **TF-IDF** method is a weighted measure which gives more importance to less frequent words in a corpus. It assigns a weight to each term(word) in a document based on **Term frequency(TF)** and **inverse document frequency(IDF)**.
#
# **TF(i,j)** = (# times word i appears in document j) / (# words in document j)
#
# **IDF(i,D)** = log_e(#documents in the corpus D) / (#documents containing word i)
#
# weight(i,j) = **TF(i,j)** x **IDF(i,D)**
#
# So if a word occurs more number of times in a document but less number of times in all other documents then its **TF-IDF** value will be high.

# %%
tfidf_headline_vectorizer = TfidfVectorizer(min_df = 0)
tfidf_headline_features = tfidf_headline_vectorizer.fit_transform(news_articles_temp['headline'])

# %%
def tfidf_based_model(row_index, num_similar_items):
    couple_dist = pairwise_distances(tfidf_headline_features,tfidf_headline_features[row_index])
    indices = np.argsort(couple_dist.ravel())[0:num_similar_items]
    df_tfidf.at[row_index,'suggestions']=indices
    dataFrame = pd.DataFrame({
               'headline':news_articles_temp['headline'][indices].values,
                'Euclidean similarity with the queried article': couple_dist[indices].ravel()})
    print("="*30,"Queried article details","="*30)
    print('headline : ',news_articles_temp['headline'][indices[0]])
    print("\n","="*25,"Recommended articles : ","="*23)
    return dataFrame.iloc[1:,]
for i in range(len(news_articles_temp)):
  print(tfidf_based_model(i, 4))
# Out:
# ============================== Queried article details ==============================
# headline :  workers consumers say theyre likely favor prolgbtq businesses study find
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  myocarditis covid vaccine low among teens young adults large study find
# 2  blacklist russian propagandists thrive rightwing apps gab truth social study find
# 3  asian americans heavily favor warnock georgia runoff exit poll show
#
#    Euclidean similarity with the queried article
# 1  1.319265
# 2  1.319534
# 3  1.347108
# ============================== Queried article details ==============================
# headline :  win ukraine could hinge side secure enough artillery ammunition
#
#  ========================= Recommended articles :  =======================
#                                                                  headline  \
# 1  donors meet paris get ukraine winter russian bomb
# 2  ancient coin unearth desert cave could point evidence maccabean revolt
# 3  us set approve send patriot missile battery ukraine
#
#    Euclidean similarity with the queried article
# 1  1.348576
# 2  1.348898
# 3  1.349865
# ============================== Queried article details ==============================
# headline :  ignition fusion breakthrough draw energy gain
#
#  ========================= Recommended articles :  =======================
#                                                                                     headline  \
# 1  house gops inclusion salacious commanders cheerleaders photos official memo draw blowback
# 2  workers consumers say theyre likely favor prolgbtq businesses study find
# 3  inflation slow 71 november another sign economy cool
#
#    Euclidean similarity with the queried article
# 1  1.337320
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  virginias open congressional seat offer opportunity new generation black leaders
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  biden admin may cut number migrants eligible asylum border open new paths others
# 2  congressional negotiators reach bipartisan agreement framework fund deal
# 3  black families phoenix child welfare investigations constant threat
#
#    Euclidean similarity with the queried article
# 1  1.315232
# 2  1.341324
# 3  1.358130
# ============================== Queried article details ==============================
# headline :  us set approve send patriot missile battery ukraine
#
#  ========================= Recommended articles :  =======================
#                                                           headline  \
# 1  donors meet paris get ukraine winter russian bomb
# 2  us postal service announce stamp honor late rep john lewis
# 3  win ukraine could hinge side secure enough artillery ammunition
#
#    Euclidean similarity with the queried article
# 1  1.344250
# 2  1.344593
# 3  1.349865
# ============================== Queried article details ==============================
# headline :  us postal service announce stamp honor late rep john lewis
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  us set approve send patriot missile battery ukraine
# 2  workers consumers say theyre likely favor prolgbtq businesses study find
# 3  lawmakers unveil bipartisan bill ban tiktok nationwide
#
#    Euclidean similarity with the queried article
# 1  1.344593
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  twitter disband trust safety council
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  elon musk astronaut scott kelly spar twitter pronoun use
# 2  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 3  lawmakers unveil bipartisan bill ban tiktok nationwide
#
#    Euclidean similarity with the queried article
# 1  1.328693
# 2  1.343077
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  twitch call allow users create charity campaign nonprofits consider controversial
#
#  ========================= Recommended articles :  =======================
#                                                          headline  \
# 1  samuel bankmanfried accuse make illegal campaign contributions
# 2  ron desantis outflank trump right call covid vaccine probe
# 3  firmageddon researchers find 11 million acres dead tree oregon
#
#    Euclidean similarity with the queried article
# 1  1.337201
# 2  1.345647
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  travel coast coast samesex couple balance act
#
#  ========================= Recommended articles :  =======================
#                                                          headline  \
# 1  biden sign samesex marriage bill white house ceremony
# 2  firmageddon researchers find 11 million acres dead tree oregon
# 3  inflation slow 71 november another sign economy cool
#
#    Euclidean similarity with the queried article
# 1  1.337898
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  tornadoes tear swaths north texas southern oklahoma
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  workers consumers say theyre likely favor prolgbtq businesses study find
# 2  inflation slow 71 november another sign economy cool
# 3  deny f22 sales ally lead ukjapanitaly stealth plane project
#
#    Euclidean similarity with the queried article
# 1  1.414214
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  tina turners son ronnie die colon cancer complications medical examiner say
#
#  ========================= Recommended articles :  =======================
#                                                                  headline  \
# 1  moderna say personalize mrna cancer vaccine effective advance melanoma
# 2  dangerous flu know symptoms sign complications
# 3  mcconnell say trump fuel candidate quality problems midterms
#
#    Euclidean similarity with the queried article
# 1  1.310635
# 2  1.333757
# 3  1.377419
# ============================== Queried article details ==============================
# headline :  ticketmaster mexico face millions fin bad bunny concert ticket screwup
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  jay leno get face full gas catch fire work garage
# 2  workers consumers say theyre likely favor prolgbtq businesses study find
# 3  lawmakers unveil bipartisan bill ban tiktok nationwide
#
#    Euclidean similarity with the queried article
# 1  1.352496
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  biggest problem harry meghans new netflix series
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  new annual ritual debate whether retouch family holiday photo
# 2  amy schumer feel like new person operations treat endometriosis
# 3  virginias open congressional seat offer opportunity new generation black leaders
#
#    Euclidean similarity with the queried article
# 1  1.359575
# 2  1.359575
# 3  1.360479
# ============================== Queried article details ==============================
# headline :  taunt black student fight back civil right complaint say 30second fight derail life
#
#  ========================= Recommended articles :  =======================
#                                                               headline  \
# 1  ron desantis outflank trump right call covid vaccine probe
# 2  student loan borrowers think get relief court put live hold
# 3  black families phoenix child welfare investigations constant threat
#
#    Euclidean similarity with the queried article
# 1  1.356944
# 2  1.361685
# 3  1.369351
# ============================== Queried article details ==============================
# headline :  student loan borrowers think get relief court put live hold
#
#  ========================= Recommended articles :  =======================
#                                                headline  \
# 1  megan thee stallion tell court tory lanez shoot feet
# 2  donors meet paris get ukraine winter russian bomb
# 3  jay leno get face full gas catch fire work garage
#
#    Euclidean similarity with the queried article
# 1  1.348397
# 2  1.351608
# 3  1.359784
# ============================== Queried article details ==============================
# headline :  state abortion restrictions higher maternal infant mortality report find
#
#  ========================= Recommended articles :  =======================
#                                                                 headline  \
# 1  research find negative effect screen time kid include higher risk ocd
# 2  park land monuments deep latino root need protection report say
# 3  2 boaters dog find safe strand sea
#
#    Euclidean similarity with the queried article
# 1  1.310459
# 2  1.345023
# 3  1.366537
# ============================== Queried article details ==============================
# headline :  scientists declare mauna loa kilauea longer erupt
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  workers consumers say theyre likely favor prolgbtq businesses study find
# 2  inflation slow 71 november another sign economy cool
# 3  deny f22 sales ally lead ukjapanitaly stealth plane project
#
#    Euclidean similarity with the queried article
# 1  1.414214
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  samuel bankmanfried accuse make illegal campaign contributions
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  protesters block construction arizona border wall make ship containers
# 2  twitch call allow users create charity campaign nonprofits consider controversial
# 3  hotel employees comedian mark curry accuse racial profile suspend notice
#
#    Euclidean similarity with the queried article
# 1  1.332741
# 2  1.337201
# 3  1.337903
# ============================== Queried article details ==============================
# headline :  ron desantis outflank trump right call covid vaccine probe
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  myocarditis covid vaccine low among teens young adults large study find
# 2  mcconnell say trump fuel candidate quality problems midterms
# 3  twitch call allow users create charity campaign nonprofits consider controversial
#
#    Euclidean similarity with the queried article
# 1  1.293069
# 2  1.334874
# 3  1.345647
# ============================== Queried article details ==============================
# headline :  research find negative effect screen time kid include higher risk ocd
#
#  ========================= Recommended articles :  =======================
#                                                                               headline  \
# 1  state abortion restrictions higher maternal infant mortality report find
# 2  next year good time buy ev many consumers 2024 might better
# 3  puerto ricos shoreline change hurricane maria heighten coastal flood risk residents
#
#    Euclidean similarity with the queried article
# 1  1.310459
# 2  1.355672
# 3  1.356637
# ============================== Queried article details ==============================
# headline :  puerto ricos shoreline change hurricane maria heighten coastal flood risk residents
#
#  ========================= Recommended articles :  =======================
#                                                                                                     headline  \
# 1  research find negative effect screen time kid include higher risk ocd
# 2  donors meet paris get ukraine winter russian bomb
# 3  disgrace ftx ceo sam bankmanfried orchestrate yearslong fraud investors customers sec criminal charge say
#
#    Euclidean similarity with the queried article
# 1  1.356637
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  protesters block construction arizona border wall make ship containers
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  samuel bankmanfried accuse make illegal campaign contributions
# 2  biden admin may cut number migrants eligible asylum border open new paths others
# 3  workers consumers say theyre likely favor prolgbtq businesses study find
#
#    Euclidean similarity with the queried article
# 1  1.332741
# 2  1.355759
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  pope francis sympathize migrant caravan seek freedom wellbeing
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  workers consumers say theyre likely favor prolgbtq businesses study find
# 2  inflation slow 71 november another sign economy cool
# 3  deny f22 sales ally lead ukjapanitaly stealth plane project
#
#    Euclidean similarity with the queried article
# 1  1.414214
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  park land monuments deep latino root need protection report say
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  state abortion restrictions higher maternal infant mortality report find
# 2  mcconnell say trump fuel candidate quality problems midterms
# 3  moderna say personalize mrna cancer vaccine effective advance melanoma
#
#    Euclidean similarity with the queried article
# 1  1.345023
# 2  1.375791
# 3  1.377572
# ============================== Queried article details ==============================
# headline :  pot debilitate heart condition link covid lesser degree vaccines
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  ron desantis outflank trump right call covid vaccine probe
# 2  myocarditis covid vaccine low among teens young adults large study find
# 3  workers consumers say theyre likely favor prolgbtq businesses study find
#
#    Euclidean similarity with the queried article
# 1  1.352053
# 2  1.357861
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  oregon gov kate brown commute sentence 17 people death row
#
#  ========================= Recommended articles :  =======================
#                                                                  headline  \
# 1  elon musk doesnt care pronouns unless nonbinary people use
# 2  firmageddon researchers find 11 million acres dead tree oregon
# 3  protesters block construction arizona border wall make ship containers
#
#    Euclidean similarity with the queried article
# 1  1.345139
# 2  1.347190
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  next year good time buy ev many consumers 2024 might better
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  tár dispel toxic lesbian stereotype find many film
# 2  workers consumers say theyre likely favor prolgbtq businesses study find
# 3  research find negative effect screen time kid include higher risk ocd
#
#    Euclidean similarity with the queried article
# 1  1.344709
# 2  1.349873
# 3  1.355672
# ============================== Queried article details ==============================
# headline :  myocarditis covid vaccine low among teens young adults large study find
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  ron desantis outflank trump right call covid vaccine probe
# 2  workers consumers say theyre likely favor prolgbtq businesses study find
# 3  blacklist russian propagandists thrive rightwing apps gab truth social study find
#
#    Euclidean similarity with the queried article
# 1  1.293069
# 2  1.319265
# 3  1.326600
# ============================== Queried article details ==============================
# headline :  moderna say personalize mrna cancer vaccine effective advance melanoma
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  tina turners son ronnie die colon cancer complications medical examiner say
# 2  ron desantis outflank trump right call covid vaccine probe
# 3  myocarditis covid vaccine low among teens young adults large study find
#
#    Euclidean similarity with the queried article
# 1  1.310635
# 2  1.349192
# 3  1.355273
# ============================== Queried article details ==============================
# headline :  michelle yeoh join cast jon chus wicked film
#
#  ========================= Recommended articles :  =======================
#                                                  headline  \
# 1  tár dispel toxic lesbian stereotype find many film
# 2  lawmakers unveil bipartisan bill ban tiktok nationwide
# 3  jay leno get face full gas catch fire work garage
#
#    Euclidean similarity with the queried article
# 1  1.333456
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  megan thee stallion tell court tory lanez shoot feet
#
#  ========================= Recommended articles :  =======================
#                                                          headline  \
# 1  student loan borrowers think get relief court put live hold
# 2  firmageddon researchers find 11 million acres dead tree oregon
# 3  dutch farmers become center global rightwing culture war
#
#    Euclidean similarity with the queried article
# 1  1.348397
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  mcconnell say trump fuel candidate quality problems midterms
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  ron desantis outflank trump right call covid vaccine probe
# 2  moderna say personalize mrna cancer vaccine effective advance melanoma
# 3  workers consumers say theyre likely favor prolgbtq businesses study find
#
#    Euclidean similarity with the queried article
# 1  1.334874
# 2  1.372765
# 3  1.373450
# ============================== Queried article details ==============================
# headline :  lawmakers unveil bipartisan bill ban tiktok nationwide
#
#  ========================= Recommended articles :  =======================
#                                                                     headline  \
# 1  biden sign samesex marriage bill white house ceremony
# 2  congressional negotiators reach bipartisan agreement framework fund deal
# 3  federal prisons suppose provide addiction medication prisoners punish use
#
#    Euclidean similarity with the queried article
# 1  1.325929
# 2  1.329778
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  jay leno get face full gas catch fire work garage
#
#  ========================= Recommended articles :  =======================
#                                                                  headline  \
# 1  donors meet paris get ukraine winter russian bomb
# 2  ticketmaster mexico face millions fin bad bunny concert ticket screwup
# 3  student loan borrowers think get relief court put live hold
#
#    Euclidean similarity with the queried article
# 1  1.352193
# 2  1.352496
# 3  1.359784
# ============================== Queried article details ==============================
# headline :  inflation slow 71 november another sign economy cool
#
#  ========================= Recommended articles :  =======================
#                                                          headline  \
# 1  dangerous flu know symptoms sign complications
# 2  biden sign samesex marriage bill white house ceremony
# 3  firmageddon researchers find 11 million acres dead tree oregon
#
#    Euclidean similarity with the queried article
# 1  1.334790
# 2  1.343889
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  deny f22 sales ally lead ukjapanitaly stealth plane project
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  workers consumers say theyre likely favor prolgbtq businesses study find
# 2  jay leno get face full gas catch fire work garage
# 3  inflation slow 71 november another sign economy cool
#
#    Euclidean similarity with the queried article
# 1  1.414214
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  dangerous flu know symptoms sign complications
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  biden sign samesex marriage bill white house ceremony
# 2  tina turners son ronnie die colon cancer complications medical examiner say
# 3  inflation slow 71 november another sign economy cool
#
#    Euclidean similarity with the queried article
# 1  1.330840
# 2  1.333757
# 3  1.334790
# ============================== Queried article details ==============================
# headline :  dutch farmers become center global rightwing culture war
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  blacklist russian propagandists thrive rightwing apps gab truth social study find
# 2  workers consumers say theyre likely favor prolgbtq businesses study find
# 3  lawmakers unveil bipartisan bill ban tiktok nationwide
#
#    Euclidean similarity with the queried article
# 1  1.345212
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  tár dispel toxic lesbian stereotype find many film
#
#  ========================= Recommended articles :  =======================
#                                                       headline  \
# 1  michelle yeoh join cast jon chus wicked film
# 2  next year good time buy ev many consumers 2024 might better
# 3  2 boaters dog find safe strand sea
#
#    Euclidean similarity with the queried article
# 1  1.333456
# 2  1.344709
# 3  1.363227
# ============================== Queried article details ==============================
# headline :  house gops inclusion salacious commanders cheerleaders photos official memo draw blowback
#
#  ========================= Recommended articles :  =======================
#                                                             headline  \
# 1  ignition fusion breakthrough draw energy gain
# 2  historymaking nonbinary government official job theft accusations
# 3  biden sign samesex marriage bill white house ceremony
#
#    Euclidean similarity with the queried article
# 1  1.337320
# 2  1.341407
# 3  1.344340
# ============================== Queried article details ==============================
# headline :  hotel employees comedian mark curry accuse racial profile suspend notice
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  samuel bankmanfried accuse make illegal campaign contributions
# 2  workers consumers say theyre likely favor prolgbtq businesses study find
# 3  lawmakers unveil bipartisan bill ban tiktok nationwide
#
#    Euclidean similarity with the queried article
# 1  1.337903
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  historymaking nonbinary government official job theft accusations
#
#  ========================= Recommended articles :  =======================
#                                                                                     headline  \
# 1  elon musk doesnt care pronouns unless nonbinary people use
# 2  house gops inclusion salacious commanders cheerleaders photos official memo draw blowback
# 3  elon musk say stop child exploitation twitter far hes ax job push watchdogs
#
#    Euclidean similarity with the queried article
# 1  1.329422
# 2  1.341407
# 3  1.343959
# ============================== Queried article details ==============================
# headline :  heres social security check feature massive 2023 cola increase start arrive
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  blacklist russian propagandists thrive rightwing apps gab truth social study find
# 2  ticketmaster mexico face millions fin bad bunny concert ticket screwup
# 3  pot debilitate heart condition link covid lesser degree vaccines
#
#    Euclidean similarity with the queried article
# 1  1.355770
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
#
#  ========================= Recommended articles :  =======================
#                                                                  headline  \
# 1  asian americans heavily favor warnock georgia runoff exit poll show
# 2  ticketmaster mexico face millions fin bad bunny concert ticket screwup
# 3  pot debilitate heart condition link covid lesser degree vaccines
#
#    Euclidean similarity with the queried article
# 1  1.362679
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  black families phoenix child welfare investigations constant threat
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 2  black women play critical role help free brittney griner
# 3  virginias open congressional seat offer opportunity new generation black leaders
#
#    Euclidean similarity with the queried article
# 1  1.348845
# 2  1.357399
# 3  1.358130
# ============================== Queried article details ==============================
# headline :  federal prisons suppose provide addiction medication prisoners punish use
#
#  ========================= Recommended articles :  =======================
#                                                      headline  \
# 1  elon musk doesnt care pronouns unless nonbinary people use
# 2  elon musk astronaut scott kelly spar twitter pronoun use
# 3  megan thee stallion tell court tory lanez shoot feet
#
#    Euclidean similarity with the queried article
# 1  1.351594
# 2  1.351840
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  facebook hit 2 billion lawsuit connect political violence africa
#
#  ========================= Recommended articles :  =======================
#                                                       headline  \
# 1  jay leno get face full gas catch fire work garage
# 2  inflation slow 71 november another sign economy cool
# 3  deny f22 sales ally lead ukjapanitaly stealth plane project
#
#    Euclidean similarity with the queried article
# 1  1.414214
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  elon musk astronaut scott kelly spar twitter pronoun use
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  elon musk doesnt care pronouns unless nonbinary people use
# 2  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 3  twitter disband trust safety council
#
#    Euclidean similarity with the queried article
# 1  1.205297
# 2  1.242643
# 3  1.328693
# ============================== Queried article details ==============================
# headline :  elon musk say stop child exploitation twitter far hes ax job push watchdogs
#
#  ========================= Recommended articles :  =======================
#                                                      headline  \
# 1  elon musk astronaut scott kelly spar twitter pronoun use
# 2  elon musk doesnt care pronouns unless nonbinary people use
# 3  twitter disband trust safety council
#
#    Euclidean similarity with the queried article
# 1  1.242643
# 2  1.301896
# 3  1.343077
# ============================== Queried article details ==============================
# headline :  elon musk doesnt care pronouns unless nonbinary people use
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  elon musk astronaut scott kelly spar twitter pronoun use
# 2  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 3  historymaking nonbinary government official job theft accusations
#
#    Euclidean similarity with the queried article
# 1  1.205297
# 2  1.301896
# 3  1.329422
# ============================== Queried article details ==============================
# headline :  donors meet paris get ukraine winter russian bomb
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  blacklist russian propagandists thrive rightwing apps gab truth social study find
# 2  us set approve send patriot missile battery ukraine
# 3  win ukraine could hinge side secure enough artillery ammunition
#
#    Euclidean similarity with the queried article
# 1  1.342469
# 2  1.344250
# 3  1.348576
# ============================== Queried article details ==============================
# headline :  disgrace ftx ceo sam bankmanfried orchestrate yearslong fraud investors customers sec criminal charge say
#
#  ========================= Recommended articles :  =======================
#                                                                  headline  \
# 1  samuel bankmanfried accuse make illegal campaign contributions
# 2  mcconnell say trump fuel candidate quality problems midterms
# 3  moderna say personalize mrna cancer vaccine effective advance melanoma
#
#    Euclidean similarity with the queried article
# 1  1.348796
# 2  1.382175
# 3  1.383657
# ============================== Queried article details ==============================
# headline :  congressional negotiators reach bipartisan agreement framework fund deal
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  lawmakers unveil bipartisan bill ban tiktok nationwide
# 2  virginias open congressional seat offer opportunity new generation black leaders
# 3  firmageddon researchers find 11 million acres dead tree oregon
#
#    Euclidean similarity with the queried article
# 1  1.329778
# 2  1.341324
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  blacklist russian propagandists thrive rightwing apps gab truth social study find
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  workers consumers say theyre likely favor prolgbtq businesses study find
# 2  myocarditis covid vaccine low among teens young adults large study find
# 3  donors meet paris get ukraine winter russian bomb
#
#    Euclidean similarity with the queried article
# 1  1.319534
# 2  1.326600
# 3  1.342469
# ============================== Queried article details ==============================
# headline :  black women play critical role help free brittney griner
#
#  ========================= Recommended articles :  =======================
#                                                                               headline  \
# 1  black families phoenix child welfare investigations constant threat
# 2  virginias open congressional seat offer opportunity new generation black leaders
# 3  taunt black student fight back civil right complaint say 30second fight derail life
#
#    Euclidean similarity with the queried article
# 1  1.357399
# 2  1.362156
# 3  1.372559
# ============================== Queried article details ==============================
# headline :  biden sign samesex marriage bill white house ceremony
#
#  ========================= Recommended articles :  =======================
#                                                  headline  \
# 1  lawmakers unveil bipartisan bill ban tiktok nationwide
# 2  dangerous flu know symptoms sign complications
# 3  travel coast coast samesex couple balance act
#
#    Euclidean similarity with the queried article
# 1  1.325929
# 2  1.330840
# 3  1.337898
# ============================== Queried article details ==============================
# headline :  biden admin may cut number migrants eligible asylum border open new paths others
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  virginias open congressional seat offer opportunity new generation black leaders
# 2  biden sign samesex marriage bill white house ceremony
# 3  protesters block construction arizona border wall make ship containers
#
#    Euclidean similarity with the queried article
# 1  1.315232
# 2  1.349160
# 3  1.355759
# ============================== Queried article details ==============================
# headline :  asian americans heavily favor warnock georgia runoff exit poll show
#
#  ========================= Recommended articles :  =======================
#                                                                      headline  \
# 1  workers consumers say theyre likely favor prolgbtq businesses study find
# 2  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
# 3  pot debilitate heart condition link covid lesser degree vaccines
#
#    Euclidean similarity with the queried article
# 1  1.347108
# 2  1.362679
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  ancient coin unearth desert cave could point evidence maccabean revolt
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  win ukraine could hinge side secure enough artillery ammunition
# 2  workers consumers say theyre likely favor prolgbtq businesses study find
# 3  lawmakers unveil bipartisan bill ban tiktok nationwide
#
#    Euclidean similarity with the queried article
# 1  1.348898
# 2  1.414214
# 3  1.414214
# ============================== Queried article details ==============================
# headline :  amy schumer feel like new person operations treat endometriosis
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  biggest problem harry meghans new netflix series
# 2  new annual ritual debate whether retouch family holiday photo
# 3  virginias open congressional seat offer opportunity new generation black leaders
#
#    Euclidean similarity with the queried article
# 1  1.359575
# 2  1.366493
# 3  1.367281
# ============================== Queried article details ==============================
# headline :  new annual ritual debate whether retouch family holiday photo
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  biggest problem harry meghans new netflix series
# 2  amy schumer feel like new person operations treat endometriosis
# 3  virginias open congressional seat offer opportunity new generation black leaders
#
#    Euclidean similarity with the queried article
# 1  1.359575
# 2  1.366493
# 3  1.367281
# ============================== Queried article details ==============================
# headline :  2 boaters dog find safe strand sea
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  tár dispel toxic lesbian stereotype find many film
# 2  state abortion restrictions higher maternal infant mortality report find
# 3  workers consumers say theyre likely favor prolgbtq businesses study find
#
#    Euclidean similarity with the queried article
# 1  1.363227
# 2  1.366537
# 3  1.366991
# ============================== Queried article details ==============================
# headline :  firmageddon researchers find 11 million acres dead tree oregon
#
#  ========================= Recommended articles :  =======================
#                                                      headline  \
# 1  oregon gov kate brown commute sentence 17 people death row
# 2  2 boaters dog find safe strand sea
# 3  tár dispel toxic lesbian stereotype find many film
#
#    Euclidean similarity with the queried article
# 1  1.347190
# 2  1.367049
# 3  1.372998

# %%
df_tfidf.to_csv('df_tfidf.csv',index=False)

# %% [markdown]
# Compared to **BoW** method, here **TF-IDF** method recommends the articles with headline containing words like "employer", "fire", "flip" in top 5 recommendations and these words occur less frequently in the corpus.

# %% [markdown]
# **Disadvantages :- **
#
# **Bow** and **TF-IDF** method do not capture **semantic** and **syntactic** similarity of a given word with other words but this can be captured using **Word embeddings**.
#
# For example: there is a good association between words like "trump" and "white house", "office and employee", "tiger" and "leopard", "USA" and "Washington D.C" etc. Such kind of **semantic** similarity can be captured using **word embedding** techniques.
# **Word embedding** techniques like **Word2Vec**, **GloVe** and **fastText** leverage semantic similarity between words.

# %% [markdown]
# ### 6.c Using Word2Vec embedding

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# **Word2Vec** is one of the techniques for **semantic** similarity which was invented by **Google** in 2013. For a given corpus, during training it observes the patterns and respresents each word by a **d-dimensional** vector. To get better results we need fairly large corpus.
#
# Since our corpus size is small so let's use Google's pretrained model on **google news** articles. This standard model contains vector representation for billions of words obtained by training on millions of new articles. Here, each word is represented by a **300** dimensional dense vector.

# %%
import gensim
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
import pickle

# %% [markdown]
# Since this **pre-trained Word2Vec** model is **1.5 GB** in compressed form. So it needs a high end RAM to load it in the memory after unzipping.
#
# Here, we are loading this pre-build model from a **pickle** file which contains this model in advance.

# %%
loaded_model = gensim.models.KeyedVectors.load_word2vec_format('/content/drive/MyDrive/Colab Notebooks/GoogleNews-vectors-negative300.bin', binary=True)

# %% [markdown]
# Since the model gives vector representation for each **word** but we calculate the distance between **headlines** so we need to obtain vector representation for each **headline**. One way to obtain this is by first adding vector representation of all the words available in the **headline** and then calculating the average. It is also known as **average Word2Vec** model.
#
# Below code cell performs the same.

# %%
loaded_model['porter']

# %%
from gensim.models import word2vec
model = gensim.models.KeyedVectors.load_word2vec_format('/content/drive/MyDrive/Colab Notebooks/GoogleNews-vectors-negative300.bin', binary=True)
model.save("file.txt")

# %%
vocabulary = model
w2v_headline = []
for i in news_articles_temp['headline']:
    w2Vec_word = np.zeros(300, dtype="float32")
    for word in i.split():
        if word in vocabulary:
            w2Vec_word = np.add(w2Vec_word, model[word])
    w2Vec_word = np.divide(w2Vec_word, len(i.split()))
    w2v_headline.append(w2Vec_word)
w2v_headline = np.array(w2v_headline)

# %%
def avg_w2v_based_model(row_index, num_similar_items):
    couple_dist = pairwise_distances(w2v_headline, w2v_headline[row_index].reshape(1,-1))
    indices = np.argsort(couple_dist.ravel())[0:num_similar_items]
    df_w2v.at[row_index,'suggestions']=indices
    dataFrame = pd.DataFrame({
               'headline':news_articles_temp['headline'][indices[0]],
                'Euclidean similarity with the queried article': couple_dist[indices].ravel()})
    print("="*30,"Queried article details","="*30)
    print('headline : ',news_articles_temp['headline'][indices[0]])
    print("\n","="*25,"Recommended articles : ","="*23)
    return dataFrame.iloc[1:,]
for i in range(len(news_articles_temp)):
  print(avg_w2v_based_model(i, 4))
# Out:
# ============================== Queried article details ==============================
# headline :  workers consumers say theyre likely favor prolgbtq businesses study find
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  workers consumers say theyre likely favor prolgbtq businesses study find
# 2  workers consumers say theyre likely favor prolgbtq businesses study find
# 3  workers consumers say theyre likely favor prolgbtq businesses study find
#
#    Euclidean similarity with the queried article
# 1  0.937121
# 2  1.017899
# 3  1.093764
# ============================== Queried article details ==============================
# headline :  win ukraine could hinge side secure enough artillery ammunition
#
#  ========================= Recommended articles :  =======================
#                                                           headline  \
# 1  win ukraine could hinge side secure enough artillery ammunition
# 2  win ukraine could hinge side secure enough artillery ammunition
# 3  win ukraine could hinge side secure enough artillery ammunition
#
#    Euclidean similarity with the queried article
# 1  1.180453
# 2  1.223832
# 3  1.245016
# ============================== Queried article details ==============================
# headline :  ignition fusion breakthrough draw energy gain
#
#  ========================= Recommended articles :  =======================
#                                         headline  \
# 1  ignition fusion breakthrough draw energy gain
# 2  ignition fusion breakthrough draw energy gain
# 3  ignition fusion breakthrough draw energy gain
#
#    Euclidean similarity with the queried article
# 1  1.450448
# 2  1.476001
# 3  1.482259
# ============================== Queried article details ==============================
# headline :  virginias open congressional seat offer opportunity new generation black leaders
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  virginias open congressional seat offer opportunity new generation black leaders
# 2  virginias open congressional seat offer opportunity new generation black leaders
# 3  virginias open congressional seat offer opportunity new generation black leaders
#
#    Euclidean similarity with the queried article
# 1  0.973718
# 2  1.039485
# 3  1.106045
# ============================== Queried article details ==============================
# headline :  us set approve send patriot missile battery ukraine
#
#  ========================= Recommended articles :  =======================
#                                               headline  \
# 1  us set approve send patriot missile battery ukraine
# 2  us set approve send patriot missile battery ukraine
# 3  us set approve send patriot missile battery ukraine
#
#    Euclidean similarity with the queried article
# 1  1.204402
# 2  1.245016
# 3  1.262010
# ============================== Queried article details ==============================
# headline :  us postal service announce stamp honor late rep john lewis
#
#  ========================= Recommended articles :  =======================
#                                                      headline  \
# 1  us postal service announce stamp honor late rep john lewis
# 2  us postal service announce stamp honor late rep john lewis
# 3  us postal service announce stamp honor late rep john lewis
#
#    Euclidean similarity with the queried article
# 1  1.129023
# 2  1.145686
# 3  1.152678
# ============================== Queried article details ==============================
# headline :  twitter disband trust safety council
#
#  ========================= Recommended articles :  =======================
#                                headline  \
# 1  twitter disband trust safety council
# 2  twitter disband trust safety council
# 3  twitter disband trust safety council
#
#    Euclidean similarity with the queried article
# 1  1.450614
# 2  1.538791
# 3  1.552784
# ============================== Queried article details ==============================
# headline :  twitch call allow users create charity campaign nonprofits consider controversial
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  twitch call allow users create charity campaign nonprofits consider controversial
# 2  twitch call allow users create charity campaign nonprofits consider controversial
# 3  twitch call allow users create charity campaign nonprofits consider controversial
#
#    Euclidean similarity with the queried article
# 1  1.083787
# 2  1.096068
# 3  1.106793
# ============================== Queried article details ==============================
# headline :  travel coast coast samesex couple balance act
#
#  ========================= Recommended articles :  =======================
#                                         headline  \
# 1  travel coast coast samesex couple balance act
# 2  travel coast coast samesex couple balance act
# 3  travel coast coast samesex couple balance act
#
#    Euclidean similarity with the queried article
# 1  1.290857
# 2  1.304694
# 3  1.310000
# ============================== Queried article details ==============================
# headline :  tornadoes tear swaths north texas southern oklahoma
#
#  ========================= Recommended articles :  =======================
#                                               headline  \
# 1  tornadoes tear swaths north texas southern oklahoma
# 2  tornadoes tear swaths north texas southern oklahoma
# 3  tornadoes tear swaths north texas southern oklahoma
#
#    Euclidean similarity with the queried article
# 1  1.610843
# 2  1.636672
# 3  1.692240
# ============================== Queried article details ==============================
# headline :  tina turners son ronnie die colon cancer complications medical examiner say
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  tina turners son ronnie die colon cancer complications medical examiner say
# 2  tina turners son ronnie die colon cancer complications medical examiner say
# 3  tina turners son ronnie die colon cancer complications medical examiner say
#
#    Euclidean similarity with the queried article
# 1  1.150057
# 2  1.228475
# 3  1.237927
# ============================== Queried article details ==============================
# headline :  ticketmaster mexico face millions fin bad bunny concert ticket screwup
#
#  ========================= Recommended articles :  =======================
#                                                                  headline  \
# 1  ticketmaster mexico face millions fin bad bunny concert ticket screwup
# 2  ticketmaster mexico face millions fin bad bunny concert ticket screwup
# 3  ticketmaster mexico face millions fin bad bunny concert ticket screwup
#
#    Euclidean similarity with the queried article
# 1  1.201730
# 2  1.216274
# 3  1.240669
# ============================== Queried article details ==============================
# headline :  biggest problem harry meghans new netflix series
#
#  ========================= Recommended articles :  =======================
#                                            headline  \
# 1  biggest problem harry meghans new netflix series
# 2  biggest problem harry meghans new netflix series
# 3  biggest problem harry meghans new netflix series
#
#    Euclidean similarity with the queried article
# 1  1.053505
# 2  1.075798
# 3  1.097534
# ============================== Queried article details ==============================
# headline :  taunt black student fight back civil right complaint say 30second fight derail life
#
#  ========================= Recommended articles :  =======================
#                                                                               headline  \
# 1  taunt black student fight back civil right complaint say 30second fight derail life
# 2  taunt black student fight back civil right complaint say 30second fight derail life
# 3  taunt black student fight back civil right complaint say 30second fight derail life
#
#    Euclidean similarity with the queried article
# 1  1.017418
# 2  1.110079
# 3  1.116689
# ============================== Queried article details ==============================
# headline :  student loan borrowers think get relief court put live hold
#
#  ========================= Recommended articles :  =======================
#                                                       headline  \
# 1  student loan borrowers think get relief court put live hold
# 2  student loan borrowers think get relief court put live hold
# 3  student loan borrowers think get relief court put live hold
#
#    Euclidean similarity with the queried article
# 1  1.081258
# 2  1.155155
# 3  1.164870
# ============================== Queried article details ==============================
# headline :  state abortion restrictions higher maternal infant mortality report find
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  state abortion restrictions higher maternal infant mortality report find
# 2  state abortion restrictions higher maternal infant mortality report find
# 3  state abortion restrictions higher maternal infant mortality report find
#
#    Euclidean similarity with the queried article
# 1  1.225338
# 2  1.253463
# 3  1.317950
# ============================== Queried article details ==============================
# headline :  scientists declare mauna loa kilauea longer erupt
#
#  ========================= Recommended articles :  =======================
#                                             headline  \
# 1  scientists declare mauna loa kilauea longer erupt
# 2  scientists declare mauna loa kilauea longer erupt
# 3  scientists declare mauna loa kilauea longer erupt
#
#    Euclidean similarity with the queried article
# 1  1.133062
# 2  1.146832
# 3  1.162020
# ============================== Queried article details ==============================
# headline :  samuel bankmanfried accuse make illegal campaign contributions
#
#  ========================= Recommended articles :  =======================
#                                                          headline  \
# 1  samuel bankmanfried accuse make illegal campaign contributions
# 2  samuel bankmanfried accuse make illegal campaign contributions
# 3  samuel bankmanfried accuse make illegal campaign contributions
#
#    Euclidean similarity with the queried article
# 1  1.102968
# 2  1.113695
# 3  1.157327
# ============================== Queried article details ==============================
# headline :  ron desantis outflank trump right call covid vaccine probe
#
#  ========================= Recommended articles :  =======================
#                                                      headline  \
# 1  ron desantis outflank trump right call covid vaccine probe
# 2  ron desantis outflank trump right call covid vaccine probe
# 3  ron desantis outflank trump right call covid vaccine probe
#
#    Euclidean similarity with the queried article
# 1  1.088125
# 2  1.118212
# 3  1.119929
# ============================== Queried article details ==============================
# headline :  research find negative effect screen time kid include higher risk ocd
#
#  ========================= Recommended articles :  =======================
#                                                                 headline  \
# 1  research find negative effect screen time kid include higher risk ocd
# 2  research find negative effect screen time kid include higher risk ocd
# 3  research find negative effect screen time kid include higher risk ocd
#
#    Euclidean similarity with the queried article
# 1  0.959960
# 2  1.017899
# 3  1.031222
# ============================== Queried article details ==============================
# headline :  puerto ricos shoreline change hurricane maria heighten coastal flood risk residents
#
#  ========================= Recommended articles :  =======================
#                                                                               headline  \
# 1  puerto ricos shoreline change hurricane maria heighten coastal flood risk residents
# 2  puerto ricos shoreline change hurricane maria heighten coastal flood risk residents
# 3  puerto ricos shoreline change hurricane maria heighten coastal flood risk residents
#
#    Euclidean similarity with the queried article
# 1  1.221385
# 2  1.238867
# 3  1.264074
# ============================== Queried article details ==============================
# headline :  protesters block construction arizona border wall make ship containers
#
#  ========================= Recommended articles :  =======================
#                                                                  headline  \
# 1  protesters block construction arizona border wall make ship containers
# 2  protesters block construction arizona border wall make ship containers
# 3  protesters block construction arizona border wall make ship containers
#
#    Euclidean similarity with the queried article
# 1  1.241166
# 2  1.277529
# 3  1.279398
# ============================== Queried article details ==============================
# headline :  pope francis sympathize migrant caravan seek freedom wellbeing
#
#  ========================= Recommended articles :  =======================
#                                                          headline  \
# 1  pope francis sympathize migrant caravan seek freedom wellbeing
# 2  pope francis sympathize migrant caravan seek freedom wellbeing
# 3  pope francis sympathize migrant caravan seek freedom wellbeing
#
#    Euclidean similarity with the queried article
# 1  1.299465
# 2  1.323290
# 3  1.337697
# ============================== Queried article details ==============================
# headline :  park land monuments deep latino root need protection report say
#
#  ========================= Recommended articles :  =======================
#                                                           headline  \
# 1  park land monuments deep latino root need protection report say
# 2  park land monuments deep latino root need protection report say
# 3  park land monuments deep latino root need protection report say
#
#    Euclidean similarity with the queried article
# 1  1.026008
# 2  1.088666
# 3  1.101332
# ============================== Queried article details ==============================
# headline :  pot debilitate heart condition link covid lesser degree vaccines
#
#  ========================= Recommended articles :  =======================
#                                                            headline  \
# 1  pot debilitate heart condition link covid lesser degree vaccines
# 2  pot debilitate heart condition link covid lesser degree vaccines
# 3  pot debilitate heart condition link covid lesser degree vaccines
#
#    Euclidean similarity with the queried article
# 1  1.156472
# 2  1.161418
# 3  1.168487
# ============================== Queried article details ==============================
# headline :  oregon gov kate brown commute sentence 17 people death row
#
#  ========================= Recommended articles :  =======================
#                                                      headline  \
# 1  oregon gov kate brown commute sentence 17 people death row
# 2  oregon gov kate brown commute sentence 17 people death row
# 3  oregon gov kate brown commute sentence 17 people death row
#
#    Euclidean similarity with the queried article
# 1  1.226013
# 2  1.231397
# 3  1.245762
# ============================== Queried article details ==============================
# headline :  next year good time buy ev many consumers 2024 might better
#
#  ========================= Recommended articles :  =======================
#                                                       headline  \
# 1  next year good time buy ev many consumers 2024 might better
# 2  next year good time buy ev many consumers 2024 might better
# 3  next year good time buy ev many consumers 2024 might better
#
#    Euclidean similarity with the queried article
# 1  0.937121
# 2  0.959960
# 3  0.965220
# ============================== Queried article details ==============================
# headline :  myocarditis covid vaccine low among teens young adults large study find
#
#  ========================= Recommended articles :  =======================
#                                                                   headline  \
# 1  myocarditis covid vaccine low among teens young adults large study find
# 2  myocarditis covid vaccine low among teens young adults large study find
# 3  myocarditis covid vaccine low among teens young adults large study find
#
#    Euclidean similarity with the queried article
# 1  1.137652
# 2  1.148734
# 3  1.186678
# ============================== Queried article details ==============================
# headline :  moderna say personalize mrna cancer vaccine effective advance melanoma
#
#  ========================= Recommended articles :  =======================
#                                                                  headline  \
# 1  moderna say personalize mrna cancer vaccine effective advance melanoma
# 2  moderna say personalize mrna cancer vaccine effective advance melanoma
# 3  moderna say personalize mrna cancer vaccine effective advance melanoma
#
#    Euclidean similarity with the queried article
# 1  1.211747
# 2  1.307083
# 3  1.332349
# ============================== Queried article details ==============================
# headline :  michelle yeoh join cast jon chus wicked film
#
#  ========================= Recommended articles :  =======================
#                                        headline  \
# 1  michelle yeoh join cast jon chus wicked film
# 2  michelle yeoh join cast jon chus wicked film
# 3  michelle yeoh join cast jon chus wicked film
#
#    Euclidean similarity with the queried article
# 1  1.114977
# 2  1.146056
# 3  1.195848
# ============================== Queried article details ==============================
# headline :  megan thee stallion tell court tory lanez shoot feet
#
#  ========================= Recommended articles :  =======================
#                                                headline  \
# 1  megan thee stallion tell court tory lanez shoot feet
# 2  megan thee stallion tell court tory lanez shoot feet
# 3  megan thee stallion tell court tory lanez shoot feet
#
#    Euclidean similarity with the queried article
# 1  1.079250
# 2  1.110161
# 3  1.114977
# ============================== Queried article details ==============================
# headline :  mcconnell say trump fuel candidate quality problems midterms
#
#  ========================= Recommended articles :  =======================
#                                                        headline  \
# 1  mcconnell say trump fuel candidate quality problems midterms
# 2  mcconnell say trump fuel candidate quality problems midterms
# 3  mcconnell say trump fuel candidate quality problems midterms
#
#    Euclidean similarity with the queried article
# 1  1.134091
# 2  1.183613
# 3  1.197571
# ============================== Queried article details ==============================
# headline :  lawmakers unveil bipartisan bill ban tiktok nationwide
#
#  ========================= Recommended articles :  =======================
#                                                  headline  \
# 1  lawmakers unveil bipartisan bill ban tiktok nationwide
# 2  lawmakers unveil bipartisan bill ban tiktok nationwide
# 3  lawmakers unveil bipartisan bill ban tiktok nationwide
#
#    Euclidean similarity with the queried article
# 1  1.398262
# 2  1.469872
# 3  1.519747
# ============================== Queried article details ==============================
# headline :  jay leno get face full gas catch fire work garage
#
#  ========================= Recommended articles :  =======================
#                                             headline  \
# 1  jay leno get face full gas catch fire work garage
# 2  jay leno get face full gas catch fire work garage
# 3  jay leno get face full gas catch fire work garage
#
#    Euclidean similarity with the queried article
# 1  1.030708
# 2  1.065328
# 3  1.067369
# ============================== Queried article details ==============================
# headline :  inflation slow 71 november another sign economy cool
#
#  ========================= Recommended articles :  =======================
#                                                headline  \
# 1  inflation slow 71 november another sign economy cool
# 2  inflation slow 71 november another sign economy cool
# 3  inflation slow 71 november another sign economy cool
#
#    Euclidean similarity with the queried article
# 1  1.131190
# 2  1.161391
# 3  1.212379
# ============================== Queried article details ==============================
# headline :  deny f22 sales ally lead ukjapanitaly stealth plane project
#
#  ========================= Recommended articles :  =======================
#                                                       headline  \
# 1  deny f22 sales ally lead ukjapanitaly stealth plane project
# 2  deny f22 sales ally lead ukjapanitaly stealth plane project
# 3  deny f22 sales ally lead ukjapanitaly stealth plane project
#
#    Euclidean similarity with the queried article
# 1  1.063650
# 2  1.089671
# 3  1.105008
# ============================== Queried article details ==============================
# headline :  dangerous flu know symptoms sign complications
#
#  ========================= Recommended articles :  =======================
#                                          headline  \
# 1  dangerous flu know symptoms sign complications
# 2  dangerous flu know symptoms sign complications
# 3  dangerous flu know symptoms sign complications
#
#    Euclidean similarity with the queried article
# 1  1.475404
# 2  1.526874
# 3  1.528160
# ============================== Queried article details ==============================
# headline :  dutch farmers become center global rightwing culture war
#
#  ========================= Recommended articles :  =======================
#                                                    headline  \
# 1  dutch farmers become center global rightwing culture war
# 2  dutch farmers become center global rightwing culture war
# 3  dutch farmers become center global rightwing culture war
#
#    Euclidean similarity with the queried article
# 1  1.143197
# 2  1.223077
# 3  1.227104
# ============================== Queried article details ==============================
# headline :  tár dispel toxic lesbian stereotype find many film
#
#  ========================= Recommended articles :  =======================
#                                              headline  \
# 1  tár dispel toxic lesbian stereotype find many film
# 2  tár dispel toxic lesbian stereotype find many film
# 3  tár dispel toxic lesbian stereotype find many film
#
#    Euclidean similarity with the queried article
# 1  1.178490
# 2  1.183843
# 3  1.199925
# ============================== Queried article details ==============================
# headline :  house gops inclusion salacious commanders cheerleaders photos official memo draw blowback
#
#  ========================= Recommended articles :  =======================
#                                                                                     headline  \
# 1  house gops inclusion salacious commanders cheerleaders photos official memo draw blowback
# 2  house gops inclusion salacious commanders cheerleaders photos official memo draw blowback
# 3  house gops inclusion salacious commanders cheerleaders photos official memo draw blowback
#
#    Euclidean similarity with the queried article
# 1  1.144785
# 2  1.176405
# 3  1.178312
# ============================== Queried article details ==============================
# headline :  hotel employees comedian mark curry accuse racial profile suspend notice
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  hotel employees comedian mark curry accuse racial profile suspend notice
# 2  hotel employees comedian mark curry accuse racial profile suspend notice
# 3  hotel employees comedian mark curry accuse racial profile suspend notice
#
#    Euclidean similarity with the queried article
# 1  1.125270
# 2  1.150674
# 3  1.185751
# ============================== Queried article details ==============================
# headline :  historymaking nonbinary government official job theft accusations
#
#  ========================= Recommended articles :  =======================
#                                                             headline  \
# 1  historymaking nonbinary government official job theft accusations
# 2  historymaking nonbinary government official job theft accusations
# 3  historymaking nonbinary government official job theft accusations
#
#    Euclidean similarity with the queried article
# 1  1.015580
# 2  1.059601
# 3  1.115271
# ============================== Queried article details ==============================
# headline :  heres social security check feature massive 2023 cola increase start arrive
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  heres social security check feature massive 2023 cola increase start arrive
# 2  heres social security check feature massive 2023 cola increase start arrive
# 3  heres social security check feature massive 2023 cola increase start arrive
#
#    Euclidean similarity with the queried article
# 1  0.965220
# 2  0.995326
# 3  1.039989
# ============================== Queried article details ==============================
# headline :  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
#
#  ========================= Recommended articles :  =======================
#                                                                      headline  \
# 1  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
# 2  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
# 3  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
#
#    Euclidean similarity with the queried article
# 1  1.072423
# 2  1.111506
# 3  1.114750
# ============================== Queried article details ==============================
# headline :  black families phoenix child welfare investigations constant threat
#
#  ========================= Recommended articles :  =======================
#                                                               headline  \
# 1  black families phoenix child welfare investigations constant threat
# 2  black families phoenix child welfare investigations constant threat
# 3  black families phoenix child welfare investigations constant threat
#
#    Euclidean similarity with the queried article
# 1  1.120260
# 2  1.160008
# 3  1.233629
# ============================== Queried article details ==============================
# headline :  federal prisons suppose provide addiction medication prisoners punish use
#
#  ========================= Recommended articles :  =======================
#                                                                     headline  \
# 1  federal prisons suppose provide addiction medication prisoners punish use
# 2  federal prisons suppose provide addiction medication prisoners punish use
# 3  federal prisons suppose provide addiction medication prisoners punish use
#
#    Euclidean similarity with the queried article
# 1  1.243243
# 2  1.293900
# 3  1.294360
# ============================== Queried article details ==============================
# headline :  facebook hit 2 billion lawsuit connect political violence africa
#
#  ========================= Recommended articles :  =======================
#                                                            headline  \
# 1  facebook hit 2 billion lawsuit connect political violence africa
# 2  facebook hit 2 billion lawsuit connect political violence africa
# 3  facebook hit 2 billion lawsuit connect political violence africa
#
#    Euclidean similarity with the queried article
# 1  1.154145
# 2  1.163471
# 3  1.200046
# ============================== Queried article details ==============================
# headline :  elon musk astronaut scott kelly spar twitter pronoun use
#
#  ========================= Recommended articles :  =======================
#                                                    headline  \
# 1  elon musk astronaut scott kelly spar twitter pronoun use
# 2  elon musk astronaut scott kelly spar twitter pronoun use
# 3  elon musk astronaut scott kelly spar twitter pronoun use
#
#    Euclidean similarity with the queried article
# 1  1.300917
# 2  1.301705
# 3  1.327731
# ============================== Queried article details ==============================
# headline :  elon musk say stop child exploitation twitter far hes ax job push watchdogs
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 2  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 3  elon musk say stop child exploitation twitter far hes ax job push watchdogs
#
#    Euclidean similarity with the queried article
# 1  0.992860
# 2  0.995326
# 3  1.006667
# ============================== Queried article details ==============================
# headline :  elon musk doesnt care pronouns unless nonbinary people use
#
#  ========================= Recommended articles :  =======================
#                                                      headline  \
# 1  elon musk doesnt care pronouns unless nonbinary people use
# 2  elon musk doesnt care pronouns unless nonbinary people use
# 3  elon musk doesnt care pronouns unless nonbinary people use
#
#    Euclidean similarity with the queried article
# 1  0.992860
# 2  1.021088
# 3  1.094560
# ============================== Queried article details ==============================
# headline :  donors meet paris get ukraine winter russian bomb
#
#  ========================= Recommended articles :  =======================
#                                             headline  \
# 1  donors meet paris get ukraine winter russian bomb
# 2  donors meet paris get ukraine winter russian bomb
# 3  donors meet paris get ukraine winter russian bomb
#
#    Euclidean similarity with the queried article
# 1  1.174955
# 2  1.215420
# 3  1.231723
# ============================== Queried article details ==============================
# headline :  disgrace ftx ceo sam bankmanfried orchestrate yearslong fraud investors customers sec criminal charge say
#
#  ========================= Recommended articles :  =======================
#                                                                                                     headline  \
# 1  disgrace ftx ceo sam bankmanfried orchestrate yearslong fraud investors customers sec criminal charge say
# 2  disgrace ftx ceo sam bankmanfried orchestrate yearslong fraud investors customers sec criminal charge say
# 3  disgrace ftx ceo sam bankmanfried orchestrate yearslong fraud investors customers sec criminal charge say
#
#    Euclidean similarity with the queried article
# 1  1.015580
# 2  1.070243
# 3  1.096926
# ============================== Queried article details ==============================
# headline :  congressional negotiators reach bipartisan agreement framework fund deal
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  congressional negotiators reach bipartisan agreement framework fund deal
# 2  congressional negotiators reach bipartisan agreement framework fund deal
# 3  congressional negotiators reach bipartisan agreement framework fund deal
#
#    Euclidean similarity with the queried article
# 1  1.398262
# 2  1.516572
# 3  1.613653
# ============================== Queried article details ==============================
# headline :  blacklist russian propagandists thrive rightwing apps gab truth social study find
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  blacklist russian propagandists thrive rightwing apps gab truth social study find
# 2  blacklist russian propagandists thrive rightwing apps gab truth social study find
# 3  blacklist russian propagandists thrive rightwing apps gab truth social study find
#
#    Euclidean similarity with the queried article
# 1  1.143197
# 2  1.157757
# 3  1.235720
# ============================== Queried article details ==============================
# headline :  black women play critical role help free brittney griner
#
#  ========================= Recommended articles :  =======================
#                                                    headline  \
# 1  black women play critical role help free brittney griner
# 2  black women play critical role help free brittney griner
# 3  black women play critical role help free brittney griner
#
#    Euclidean similarity with the queried article
# 1  0.973718
# 2  0.997318
# 3  1.031222
# ============================== Queried article details ==============================
# headline :  biden sign samesex marriage bill white house ceremony
#
#  ========================= Recommended articles :  =======================
#                                                 headline  \
# 1  biden sign samesex marriage bill white house ceremony
# 2  biden sign samesex marriage bill white house ceremony
# 3  biden sign samesex marriage bill white house ceremony
#
#    Euclidean similarity with the queried article
# 1  1.215049
# 2  1.241248
# 3  1.249868
# ============================== Queried article details ==============================
# headline :  biden admin may cut number migrants eligible asylum border open new paths others
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  biden admin may cut number migrants eligible asylum border open new paths others
# 2  biden admin may cut number migrants eligible asylum border open new paths others
# 3  biden admin may cut number migrants eligible asylum border open new paths others
#
#    Euclidean similarity with the queried article
# 1  1.120338
# 2  1.125514
# 3  1.126489
# ============================== Queried article details ==============================
# headline :  asian americans heavily favor warnock georgia runoff exit poll show
#
#  ========================= Recommended articles :  =======================
#                                                               headline  \
# 1  asian americans heavily favor warnock georgia runoff exit poll show
# 2  asian americans heavily favor warnock georgia runoff exit poll show
# 3  asian americans heavily favor warnock georgia runoff exit poll show
#
#    Euclidean similarity with the queried article
# 1  1.261381
# 2  1.317755
# 3  1.328768
# ============================== Queried article details ==============================
# headline :  ancient coin unearth desert cave could point evidence maccabean revolt
#
#  ========================= Recommended articles :  =======================
#                                                                  headline  \
# 1  ancient coin unearth desert cave could point evidence maccabean revolt
# 2  ancient coin unearth desert cave could point evidence maccabean revolt
# 3  ancient coin unearth desert cave could point evidence maccabean revolt
#
#    Euclidean similarity with the queried article
# 1  1.181248
# 2  1.220471
# 3  1.241216
# ============================== Queried article details ==============================
# headline :  amy schumer feel like new person operations treat endometriosis
#
#  ========================= Recommended articles :  =======================
#                                                           headline  \
# 1  amy schumer feel like new person operations treat endometriosis
# 2  amy schumer feel like new person operations treat endometriosis
# 3  amy schumer feel like new person operations treat endometriosis
#
#    Euclidean similarity with the queried article
# 1  1.008585
# 2  1.021088
# 3  1.032218
# ============================== Queried article details ==============================
# headline :  new annual ritual debate whether retouch family holiday photo
#
#  ========================= Recommended articles :  =======================
#                                                         headline  \
# 1  new annual ritual debate whether retouch family holiday photo
# 2  new annual ritual debate whether retouch family holiday photo
# 3  new annual ritual debate whether retouch family holiday photo
#
#    Euclidean similarity with the queried article
# 1  1.172028
# 2  1.206772
# 3  1.225034
# ============================== Queried article details ==============================
# headline :  2 boaters dog find safe strand sea
#
#  ========================= Recommended articles :  =======================
#                              headline  \
# 1  2 boaters dog find safe strand sea
# 2  2 boaters dog find safe strand sea
# 3  2 boaters dog find safe strand sea
#
#    Euclidean similarity with the queried article
# 1  1.264074
# 2  1.311763
# 3  1.318662
# ============================== Queried article details ==============================
# headline :  firmageddon researchers find 11 million acres dead tree oregon
#
#  ========================= Recommended articles :  =======================
#                                                          headline  \
# 1  firmageddon researchers find 11 million acres dead tree oregon
# 2  firmageddon researchers find 11 million acres dead tree oregon
# 3  firmageddon researchers find 11 million acres dead tree oregon
#
#    Euclidean similarity with the queried article
# 1  1.088666
# 2  1.171336
# 3  1.189938

# %%
df_w2v.to_csv('df_w2v.csv',index=False)

# %% [markdown]
# Here, **Word2Vec** based representation recommends the headlines containing the word **white house** which is associated with the word **trump** in the queried article. Similarly, it recommends the headlines with words like "offical", "insist" which have semantic similarity to the words "employer", "sue" in the queried headline.

# %% [markdown]
# So far we were recommending using only one feature i.e. **headline** but in order to make a **robust** recommender system we need to consider **multiple** features at a time. Based on the business interest and rules, we can decide weight for each feature.
#
# Let's see different models with combinations of different features for article similarity.

# %% [markdown]
# ### 6.d Weighted similarity based on headline and category

# %% [markdown]
# Let's first see articles similarity based on **headline** and **category**. We are using **onehot encoding** to get feature representation for **category**.
#
# Sometimes as per the business requirements, we may need to give more preference to the articles from the same **category**. In such cases we can assign more weight to **category** while recommending. Higher the weight, more the significance. Similarly less weight leads to less signficance to a particular feature.

# %%
from sklearn.preprocessing import OneHotEncoder 
import numpy as np

# %%
category_onehot_encoded = OneHotEncoder().fit_transform(np.array(news_articles_temp["category"]).reshape(-1,1))

# %%
import json
from json import JSONEncoder
import numpy

class NumpyArrayEncoder(JSONEncoder):
    def default(self, obj):
        if isinstance(obj, numpy.ndarray):
            return obj.tolist()
        return JSONEncoder.default(self, obj)

# %%
def avg_w2v_with_category(row_index, num_similar_items, w1,w2): #headline_preference = True, category_preference = False):
    w2v_dist  = pairwise_distances(w2v_headline, w2v_headline[row_index].reshape(1,-1))
    category_dist = pairwise_distances(category_onehot_encoded, category_onehot_encoded[row_index]) + 1
    weighted_couple_dist   = (w1 * w2v_dist +  w2 * category_dist)/float(w1 + w2)
    indices = np.argsort(weighted_couple_dist.flatten())[0:num_similar_items].tolist()
    df_onehot.at[row_index,'suggestions']= list(indices)
    df = pd.DataFrame({
               'headline':news_articles_temp['headline'][indices].values,
                'Weighted Euclidean similarity with the queried article': weighted_couple_dist[indices].ravel(),
                'Word2Vec based Euclidean similarity': w2v_dist[indices].ravel(),
                 'Category based Euclidean similarity': category_dist[indices].ravel(),
                'Categoty': news_articles_temp['category'][indices].values})
    
    print("="*30,"Queried article details","="*30)
    print('headline : ',news_articles_temp['headline'][indices[0]])
    print('Categoty : ', news_articles_temp['category'][indices[0]])
    print("\n","="*25,"Recommended articles : ","="*23)
    return df.iloc[1:, ]

for i in range(len(news_articles_temp)):
  print(avg_w2v_with_category(i,4,0.1,0.8))
# Out:
# ============================== Queried article details ==============================
# headline :  workers consumers say theyre likely favor prolgbtq businesses study find
# Categoty :  tech
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  research find negative effect screen time kid include higher risk ocd
# 2  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 3  amy schumer feel like new person operations treat endometriosis
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.001989
# 2  1.010418
# 3  1.014795
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.017899                             1.0
# 2  1.093764                             1.0
# 3  1.133159                             1.0
#
#   Categoty
# 1  tech
# 2  tech
# 3  tech
# ============================== Queried article details ==============================
# headline :  win ukraine could hinge side secure enough artillery ammunition
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                       headline  \
# 1  next year good time buy ev many consumers 2024 might better
# 2  deny f22 sales ally lead ukjapanitaly stealth plane project
# 3  us set approve send patriot missile battery ukraine
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.020050
# 2  1.024870
# 3  1.027224
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.180453                             1.0
# 2  1.223832                             1.0
# 3  1.245016                             1.0
#
#    Categoty
# 1  business
# 2  business
# 3  business
# ============================== Queried article details ==============================
# headline :  ignition fusion breakthrough draw energy gain
# Categoty :  tech
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  research find negative effect screen time kid include higher risk ocd
# 2  scientists declare mauna loa kilauea longer erupt
# 3  elon musk say stop child exploitation twitter far hes ax job push watchdogs
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.052889
# 2  1.063392
# 3  1.065322
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.476001                             1.0
# 2  1.570531                             1.0
# 3  1.587900                             1.0
#
#   Categoty
# 1  tech
# 2  tech
# 3  tech
# ============================== Queried article details ==============================
# headline :  virginias open congressional seat offer opportunity new generation black leaders
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  black women play critical role help free brittney griner
# 2  biden admin may cut number migrants eligible asylum border open new paths others
# 3  twitch call allow users create charity campaign nonprofits consider controversial
#
#    Weighted Euclidean similarity with the queried article  \
# 1  0.997080
# 2  1.017258
# 3  1.020917
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  0.973718                             1.0
# 2  1.155321                             1.0
# 3  1.188252                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  us set approve send patriot missile battery ukraine
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                           headline  \
# 1  deny f22 sales ally lead ukjapanitaly stealth plane project
# 2  win ukraine could hinge side secure enough artillery ammunition
# 3  next year good time buy ev many consumers 2024 might better
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.022711
# 2  1.027224
# 3  1.029112
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.204402                             1.0
# 2  1.245016                             1.0
# 3  1.262010                             1.0
#
#    Categoty
# 1  business
# 2  business
# 3  business
# ============================== Queried article details ==============================
# headline :  us postal service announce stamp honor late rep john lewis
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                          headline  \
# 1  biden sign samesex marriage bill white house ceremony
# 2  ron desantis outflank trump right call covid vaccine probe
# 3  samuel bankmanfried accuse make illegal campaign contributions
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.023894
# 2  1.028759
# 3  1.030348
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.215049                             1.0
# 2  1.258834                             1.0
# 3  1.273129                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  twitter disband trust safety council
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  twitch call allow users create charity campaign nonprofits consider controversial
# 2  historymaking nonbinary government official job theft accusations
# 3  facebook hit 2 billion lawsuit connect political violence africa
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.061420
# 2  1.061944
# 3  1.067898
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.552784                             1.0
# 2  1.557493                             1.0
# 3  1.611080                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  twitch call allow users create charity campaign nonprofits consider controversial
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  black women play critical role help free brittney griner
# 2  samuel bankmanfried accuse make illegal campaign contributions
# 3  virginias open congressional seat offer opportunity new generation black leaders
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.009310
# 2  1.012633
# 3  1.020917
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.083787                             1.0
# 2  1.113695                             1.0
# 3  1.188252                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  travel coast coast samesex couple balance act
# Categoty :  entertainment
#
#  ========================= Recommended articles :  =======================
#                                                                               headline  \
# 1  jay leno get face full gas catch fire work garage
# 2  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
# 3  taunt black student fight back civil right complaint say 30second fight derail life
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.040029
# 2  1.044929
# 3  1.045074
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.360265                             1.0
# 2  1.404361                             1.0
# 3  1.405665                             1.0
#
#         Categoty
# 1  entertainment
# 2  entertainment
# 3  entertainment
# ============================== Queried article details ==============================
# headline :  tornadoes tear swaths north texas southern oklahoma
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                                               headline  \
# 1  firmageddon researchers find 11 million acres dead tree oregon
# 2  puerto ricos shoreline change hurricane maria heighten coastal flood risk residents
# 3  donors meet paris get ukraine winter russian bomb
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.067871
# 2  1.070741
# 3  1.088167
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.610843                             1.0
# 2  1.636672                             1.0
# 3  1.793506                             1.0
#
#    Categoty
# 1  business
# 2  business
# 3  business
# ============================== Queried article details ==============================
# headline :  tina turners son ronnie die colon cancer complications medical examiner say
# Categoty :  entertainment
#
#  ========================= Recommended articles :  =======================
#                                                                               headline  \
# 1  taunt black student fight back civil right complaint say 30second fight derail life
# 2  jay leno get face full gas catch fire work garage
# 3  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.034748
# 2  1.035335
# 3  1.035800
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.312736                             1.0
# 2  1.318019                             1.0
# 3  1.322197                             1.0
#
#         Categoty
# 1  entertainment
# 2  entertainment
# 3  entertainment
# ============================== Queried article details ==============================
# headline :  ticketmaster mexico face millions fin bad bunny concert ticket screwup
# Categoty :  tech
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 2  amy schumer feel like new person operations treat endometriosis
# 3  research find negative effect screen time kid include higher risk ocd
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.024030
# 2  1.035024
# 3  1.041081
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.216274                             1.0
# 2  1.315216                             1.0
# 3  1.369726                             1.0
#
#   Categoty
# 1  tech
# 2  tech
# 3  tech
# ============================== Queried article details ==============================
# headline :  biggest problem harry meghans new netflix series
# Categoty :  entertainment
#
#  ========================= Recommended articles :  =======================
#                                                                      headline  \
# 1  jay leno get face full gas catch fire work garage
# 2  michelle yeoh join cast jon chus wicked film
# 3  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.020007
# 2  1.026942
# 3  1.031928
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.180063                             1.0
# 2  1.242480                             1.0
# 3  1.287350                             1.0
#
#         Categoty
# 1  entertainment
# 2  entertainment
# 3  entertainment
# ============================== Queried article details ==============================
# headline :  taunt black student fight back civil right complaint say 30second fight derail life
# Categoty :  entertainment
#
#  ========================= Recommended articles :  =======================
#                                                                      headline  \
# 1  jay leno get face full gas catch fire work garage
# 2  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
# 3  tár dispel toxic lesbian stereotype find many film
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.013089
# 2  1.031002
# 3  1.032186
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.117798                             1.0
# 2  1.279017                             1.0
# 3  1.289671                             1.0
#
#         Categoty
# 1  entertainment
# 2  entertainment
# 3  entertainment
# ============================== Queried article details ==============================
# headline :  student loan borrowers think get relief court put live hold
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  black women play critical role help free brittney griner
# 2  twitch call allow users create charity campaign nonprofits consider controversial
# 3  biden admin may cut number migrants eligible asylum border open new paths others
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.025519
# 2  1.026207
# 3  1.028448
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.229674                             1.0
# 2  1.235864                             1.0
# 3  1.256030                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  state abortion restrictions higher maternal infant mortality report find
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  pot debilitate heart condition link covid lesser degree vaccines
# 2  black women play critical role help free brittney griner
# 3  biden admin may cut number migrants eligible asylum border open new paths others
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.035328
# 2  1.045149
# 3  1.048206
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.317950                             1.0
# 2  1.406345                             1.0
# 3  1.433854                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  scientists declare mauna loa kilauea longer erupt
# Categoty :  tech
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  elon musk doesnt care pronouns unless nonbinary people use
# 2  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 3  research find negative effect screen time kid include higher risk ocd
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.014785
# 2  1.016315
# 3  1.019016
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.133062                             1.0
# 2  1.146832                             1.0
# 3  1.171146                             1.0
#
#   Categoty
# 1  tech
# 2  tech
# 3  tech
# ============================== Queried article details ==============================
# headline :  samuel bankmanfried accuse make illegal campaign contributions
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  twitch call allow users create charity campaign nonprofits consider controversial
# 2  historymaking nonbinary government official job theft accusations
# 3  ron desantis outflank trump right call covid vaccine probe
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.012633
# 2  1.019336
# 3  1.020928
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.113695                             1.0
# 2  1.174026                             1.0
# 3  1.188348                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  ron desantis outflank trump right call covid vaccine probe
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                            headline  \
# 1  pot debilitate heart condition link covid lesser degree vaccines
# 2  samuel bankmanfried accuse make illegal campaign contributions
# 3  black women play critical role help free brittney griner
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.018721
# 2  1.020928
# 3  1.023645
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.168487                             1.0
# 2  1.188348                             1.0
# 3  1.212805                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  research find negative effect screen time kid include higher risk ocd
# Categoty :  tech
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  workers consumers say theyre likely favor prolgbtq businesses study find
# 2  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 3  amy schumer feel like new person operations treat endometriosis
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.001989
# 2  1.008099
# 3  1.008256
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.017899                             1.0
# 2  1.072887                             1.0
# 3  1.074305                             1.0
#
#   Categoty
# 1  tech
# 2  tech
# 3  tech
# ============================== Queried article details ==============================
# headline :  puerto ricos shoreline change hurricane maria heighten coastal flood risk residents
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                                                     headline  \
# 1  heres social security check feature massive 2023 cola increase start arrive
# 2  next year good time buy ev many consumers 2024 might better
# 3  house gops inclusion salacious commanders cheerleaders photos official memo draw blowback
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.026541
# 2  1.034849
# 3  1.038356
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.238867                             1.0
# 2  1.313637                             1.0
# 3  1.345204                             1.0
#
#    Categoty
# 1  business
# 2  business
# 3  business
# ============================== Queried article details ==============================
# headline :  protesters block construction arizona border wall make ship containers
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  biden admin may cut number migrants eligible asylum border open new paths others
# 2  ancient coin unearth desert cave could point evidence maccabean revolt
# 3  historymaking nonbinary government official job theft accusations
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.026796
# 2  1.044150
# 3  1.044203
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.241166                             1.0
# 2  1.397350                             1.0
# 3  1.397829                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  pope francis sympathize migrant caravan seek freedom wellbeing
# Categoty :  entertainment
#
#  ========================= Recommended articles :  =======================
#                                                                               headline  \
# 1  taunt black student fight back civil right complaint say 30second fight derail life
# 2  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
# 3  tár dispel toxic lesbian stereotype find many film
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.043875
# 2  1.051241
# 3  1.051804
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.394878                             1.0
# 2  1.461166                             1.0
# 3  1.466236                             1.0
#
#         Categoty
# 1  entertainment
# 2  entertainment
# 3  entertainment
# ============================== Queried article details ==============================
# headline :  park land monuments deep latino root need protection report say
# Categoty :  tech
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 2  elon musk doesnt care pronouns unless nonbinary people use
# 3  workers consumers say theyre likely favor prolgbtq businesses study find
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.002890
# 2  1.011259
# 3  1.017869
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.026008                             1.0
# 2  1.101332                             1.0
# 3  1.160817                             1.0
#
#   Categoty
# 1  tech
# 2  tech
# 3  tech
# ============================== Queried article details ==============================
# headline :  pot debilitate heart condition link covid lesser degree vaccines
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                        headline  \
# 1  ron desantis outflank trump right call covid vaccine probe
# 2  black women play critical role help free brittney griner
# 3  mcconnell say trump fuel candidate quality problems midterms
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.018721
# 2  1.019321
# 3  1.033790
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.168487                             1.0
# 2  1.173890                             1.0
# 3  1.304108                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  oregon gov kate brown commute sentence 17 people death row
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  biden admin may cut number migrants eligible asylum border open new paths others
# 2  biden sign samesex marriage bill white house ceremony
# 3  us postal service announce stamp honor late rep john lewis
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.033192
# 2  1.034969
# 3  1.038542
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.298729                             1.0
# 2  1.314720                             1.0
# 3  1.346876                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  next year good time buy ev many consumers 2024 might better
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                                                                     headline  \
# 1  heres social security check feature massive 2023 cola increase start arrive
# 2  disgrace ftx ceo sam bankmanfried orchestrate yearslong fraud investors customers sec criminal charge say
# 3  inflation slow 71 november another sign economy cool
#
#    Weighted Euclidean similarity with the queried article  \
# 1  0.996136
# 2  1.010770
# 3  1.014577
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  0.965220                             1.0
# 2  1.096926                             1.0
# 3  1.131190                             1.0
#
#    Categoty
# 1  business
# 2  business
# 3  business
# ============================== Queried article details ==============================
# headline :  myocarditis covid vaccine low among teens young adults large study find
# Categoty :  tech
#
#  ========================= Recommended articles :  =======================
#                                                                    headline  \
# 1  research find negative effect screen time kid include higher risk ocd
# 2  workers consumers say theyre likely favor prolgbtq businesses study find
# 3  moderna say personalize mrna cancer vaccine effective advance melanoma
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.015295
# 2  1.016526
# 3  1.023527
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.137652                             1.0
# 2  1.148734                             1.0
# 3  1.211747                             1.0
#
#   Categoty
# 1  tech
# 2  tech
# 3  tech
# ============================== Queried article details ==============================
# headline :  moderna say personalize mrna cancer vaccine effective advance melanoma
# Categoty :  tech
#
#  ========================= Recommended articles :  =======================
#                                                                   headline  \
# 1  myocarditis covid vaccine low among teens young adults large study find
# 2  amy schumer feel like new person operations treat endometriosis
# 3  research find negative effect screen time kid include higher risk ocd
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.023527
# 2  1.034120
# 3  1.041393
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.211747                             1.0
# 2  1.307083                             1.0
# 3  1.372541                             1.0
#
#   Categoty
# 1  tech
# 2  tech
# 3  tech
# ============================== Queried article details ==============================
# headline :  michelle yeoh join cast jon chus wicked film
# Categoty :  entertainment
#
#  ========================= Recommended articles :  =======================
#                                                                      headline  \
# 1  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
# 2  jay leno get face full gas catch fire work garage
# 3  biggest problem harry meghans new netflix series
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.023464
# 2  1.025912
# 3  1.026942
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.211178                             1.0
# 2  1.233207                             1.0
# 3  1.242480                             1.0
#
#         Categoty
# 1  entertainment
# 2  entertainment
# 3  entertainment
# ============================== Queried article details ==============================
# headline :  megan thee stallion tell court tory lanez shoot feet
# Categoty :  sport
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 2  jay leno get face full gas catch fire work garage
# 3  michelle yeoh join cast jon chus wicked film
#
#    Weighted Euclidean similarity with the queried article  \
# 1  2.265884
# 2  2.269319
# 3  2.269854
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.079250                             2.414214
# 2  1.110161                             2.414214
# 3  1.114977                             2.414214
#
#         Categoty
# 1  tech
# 2  entertainment
# 3  entertainment
# ============================== Queried article details ==============================
# headline :  mcconnell say trump fuel candidate quality problems midterms
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  virginias open congressional seat offer opportunity new generation black leaders
# 2  ron desantis outflank trump right call covid vaccine probe
# 3  black women play critical role help free brittney griner
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.022209
# 2  1.024475
# 3  1.031438
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.199882                             1.0
# 2  1.220276                             1.0
# 3  1.282943                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  lawmakers unveil bipartisan bill ban tiktok nationwide
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  congressional negotiators reach bipartisan agreement framework fund deal
# 2  virginias open congressional seat offer opportunity new generation black leaders
# 3  twitch call allow users create charity campaign nonprofits consider controversial
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.044251
# 2  1.052208
# 3  1.057750
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.398262                             1.0
# 2  1.469872                             1.0
# 3  1.519747                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  jay leno get face full gas catch fire work garage
# Categoty :  entertainment
#
#  ========================= Recommended articles :  =======================
#                                                                               headline  \
# 1  taunt black student fight back civil right complaint say 30second fight derail life
# 2  biggest problem harry meghans new netflix series
# 3  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.013089
# 2  1.020007
# 3  1.021602
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.117798                             1.0
# 2  1.180063                             1.0
# 3  1.194415                             1.0
#
#         Categoty
# 1  entertainment
# 2  entertainment
# 3  entertainment
# ============================== Queried article details ==============================
# headline :  inflation slow 71 november another sign economy cool
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  next year good time buy ev many consumers 2024 might better
# 2  heres social security check feature massive 2023 cola increase start arrive
# 3  deny f22 sales ally lead ukjapanitaly stealth plane project
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.014577
# 2  1.017932
# 3  1.031531
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.131190                             1.0
# 2  1.161391                             1.0
# 3  1.283783                             1.0
#
#    Categoty
# 1  business
# 2  business
# 3  business
# ============================== Queried article details ==============================
# headline :  deny f22 sales ally lead ukjapanitaly stealth plane project
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                                                                     headline  \
# 1  heres social security check feature massive 2023 cola increase start arrive
# 2  next year good time buy ev many consumers 2024 might better
# 3  disgrace ftx ceo sam bankmanfried orchestrate yearslong fraud investors customers sec criminal charge say
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.011668
# 2  1.015153
# 3  1.016717
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.105008                             1.0
# 2  1.136376                             1.0
# 3  1.150451                             1.0
#
#    Categoty
# 1  business
# 2  business
# 3  business
# ============================== Queried article details ==============================
# headline :  dangerous flu know symptoms sign complications
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  next year good time buy ev many consumers 2024 might better
# 2  heres social security check feature massive 2023 cola increase start arrive
# 3  inflation slow 71 november another sign economy cool
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.071217
# 2  1.081931
# 3  1.081968
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.640950                             1.0
# 2  1.737380                             1.0
# 3  1.737712                             1.0
#
#    Categoty
# 1  business
# 2  business
# 3  business
# ============================== Queried article details ==============================
# headline :  dutch farmers become center global rightwing culture war
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  black women play critical role help free brittney griner
# 2  virginias open congressional seat offer opportunity new generation black leaders
# 3  ron desantis outflank trump right call covid vaccine probe
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.028757
# 2  1.033317
# 3  1.035358
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.258817                             1.0
# 2  1.299854                             1.0
# 3  1.318218                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  tár dispel toxic lesbian stereotype find many film
# Categoty :  entertainment
#
#  ========================= Recommended articles :  =======================
#                                                                               headline  \
# 1  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
# 2  taunt black student fight back civil right complaint say 30second fight derail life
# 3  michelle yeoh join cast jon chus wicked film
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.026825
# 2  1.032186
# 3  1.035886
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.241426                             1.0
# 2  1.289671                             1.0
# 3  1.322975                             1.0
#
#         Categoty
# 1  entertainment
# 2  entertainment
# 3  entertainment
# ============================== Queried article details ==============================
# headline :  house gops inclusion salacious commanders cheerleaders photos official memo draw blowback
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  heres social security check feature massive 2023 cola increase start arrive
# ...
# 3  1.101332                             1.0
#
#   Categoty
# 1  tech
# 2  tech
# 3  tech
# ============================== Queried article details ==============================
# headline :  donors meet paris get ukraine winter russian bomb
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  heres social security check feature massive 2023 cola increase start arrive
# 2  next year good time buy ev many consumers 2024 might better
# 3  us set approve send patriot missile battery ukraine
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.023936
# 2  1.025747
# 3  1.036792
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.215420                             1.0
# 2  1.231723                             1.0
# 3  1.331126                             1.0
#
#    Categoty
# 1  business
# 2  business
# 3  business
# ============================== Queried article details ==============================
# headline :  disgrace ftx ceo sam bankmanfried orchestrate yearslong fraud investors customers sec criminal charge say
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  next year good time buy ev many consumers 2024 might better
# 2  deny f22 sales ally lead ukjapanitaly stealth plane project
# 3  heres social security check feature massive 2023 cola increase start arrive
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.010770
# 2  1.016717
# 3  1.018047
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.096926                             1.0
# 2  1.150451                             1.0
# 3  1.162426                             1.0
#
#    Categoty
# 1  business
# 2  business
# 3  business
# ============================== Queried article details ==============================
# headline :  congressional negotiators reach bipartisan agreement framework fund deal
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  lawmakers unveil bipartisan bill ban tiktok nationwide
# 2  virginias open congressional seat offer opportunity new generation black leaders
# 3  historymaking nonbinary government official job theft accusations
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.044251
# 2  1.057397
# 3  1.075387
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.398262                             1.0
# 2  1.516572                             1.0
# 3  1.678485                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  blacklist russian propagandists thrive rightwing apps gab truth social study find
# Categoty :  tech
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 2  park land monuments deep latino root need protection report say
# 3  workers consumers say theyre likely favor prolgbtq businesses study find
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.017529
# 2  1.029648
# 3  1.030553
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.157757                             1.0
# 2  1.266830                             1.0
# 3  1.274973                             1.0
#
#   Categoty
# 1  tech
# 2  tech
# 3  tech
# ============================== Queried article details ==============================
# headline :  black women play critical role help free brittney griner
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                             headline  \
# 1  virginias open congressional seat offer opportunity new generation black leaders
# 2  twitch call allow users create charity campaign nonprofits consider controversial
# 3  pot debilitate heart condition link covid lesser degree vaccines
#
#    Weighted Euclidean similarity with the queried article  \
# 1  0.997080
# 2  1.009310
# 3  1.019321
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  0.973718                             1.0
# 2  1.083787                             1.0
# 3  1.173890                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  biden sign samesex marriage bill white house ceremony
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  us postal service announce stamp honor late rep john lewis
# 2  virginias open congressional seat offer opportunity new generation black leaders
# 3  oregon gov kate brown commute sentence 17 people death row
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.023894
# 2  1.030730
# 3  1.034969
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.215049                             1.0
# 2  1.276572                             1.0
# 3  1.314720                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  biden admin may cut number migrants eligible asylum border open new paths others
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  virginias open congressional seat offer opportunity new generation black leaders
# 2  black women play critical role help free brittney griner
# 3  historymaking nonbinary government official job theft accusations
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.017258
# 2  1.019791
# 3  1.024274
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.155321                             1.0
# 2  1.178120                             1.0
# 3  1.218467                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  asian americans heavily favor warnock georgia runoff exit poll show
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                            headline  \
# 1  mcconnell say trump fuel candidate quality problems midterms
# 2  oregon gov kate brown commute sentence 17 people death row
# 3  facebook hit 2 billion lawsuit connect political violence africa
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.039949
# 2  1.041526
# 3  1.043380
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.359541                             1.0
# 2  1.373737                             1.0
# 3  1.390419                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  ancient coin unearth desert cave could point evidence maccabean revolt
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  virginias open congressional seat offer opportunity new generation black leaders
# 2  black women play critical role help free brittney griner
# 3  biden admin may cut number migrants eligible asylum border open new paths others
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.036835
# 2  1.037003
# 3  1.037987
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.331514                             1.0
# 2  1.333027                             1.0
# 3  1.341881                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  amy schumer feel like new person operations treat endometriosis
# Categoty :  tech
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  elon musk doesnt care pronouns unless nonbinary people use
# 2  elon musk say stop child exploitation twitter far hes ax job push watchdogs
# 3  research find negative effect screen time kid include higher risk ocd
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.002343
# 2  1.003580
# 3  1.008256
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.021088                             1.0
# 2  1.032218                             1.0
# 3  1.074305                             1.0
#
#   Categoty
# 1  tech
# 2  tech
# 3  tech
# ============================== Queried article details ==============================
# headline :  new annual ritual debate whether retouch family holiday photo
# Categoty :  entertainment
#
#  ========================= Recommended articles :  =======================
#                                                                               headline  \
# 1  hair oil cup tea moms beauty secrets welcome south asian gen zs auntie era
# 2  jay leno get face full gas catch fire work garage
# 3  taunt black student fight back civil right complaint say 30second fight derail life
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.029167
# 2  1.030719
# 3  1.033751
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.262506                             1.0
# 2  1.276470                             1.0
# 3  1.303759                             1.0
#
#         Categoty
# 1  entertainment
# 2  entertainment
# 3  entertainment
# ============================== Queried article details ==============================
# headline :  2 boaters dog find safe strand sea
# Categoty :  politics
#
#  ========================= Recommended articles :  =======================
#                                                                            headline  \
# 1  biden admin may cut number migrants eligible asylum border open new paths others
# 2  black women play critical role help free brittney griner
# 3  protesters block construction arizona border wall make ship containers
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.042267
# 2  1.042520
# 3  1.046609
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.380404                             1.0
# 2  1.382677                             1.0
# 3  1.419479                             1.0
#
#    Categoty
# 1  politics
# 2  politics
# 3  politics
# ============================== Queried article details ==============================
# headline :  firmageddon researchers find 11 million acres dead tree oregon
# Categoty :  business
#
#  ========================= Recommended articles :  =======================
#                                                                       headline  \
# 1  next year good time buy ev many consumers 2024 might better
# 2  heres social security check feature massive 2023 cola increase start arrive
# 3  deny f22 sales ally lead ukjapanitaly stealth plane project
#
#    Weighted Euclidean similarity with the queried article  \
# 1  1.021104
# 2  1.024372
# 3  1.029388
#
#    Word2Vec based Euclidean similarity  Category based Euclidean similarity  \
# 1  1.189938                             1.0
# 2  1.219349                             1.0
# 3  1.264488                             1.0
#
#    Categoty
# 1  business
# 2  business
# 3  business

# %%
temp1 = df_w2v.to_dict('records')

# %%
for i in range(len(temp1)):
  type(temp1[i]['suggestions'])
  del temp1[i]['Unnamed: 0']

# %%
df_w2v.to_csv('temp1.csv',index=False)

# %% [markdown]
# Above function takes two extra arguments **w1** and **w2** for weights corresponding to **headline** and **category**. It is always a good practice to pass the **weights** in a range scaled from **0 to 1**, where a value close to 1 indicates high weight whereas close to 0 indicates less weight.
#
# Here, we can observe that the recommended articles are from the same **category** as the queried article **category**. This is due to passing of high value to **w2**.

# %% [markdown]
# ### 7. Connecting to the MongoDb databse

# %%
! python -m pip install pymongo==3.7.2
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pymongo==3.7.2
#   Downloading pymongo-3.7.2.tar.gz (628 kB)
#      |████████████████████████████████| 628 kB 4.2 MB/s
# Building wheels for collected packages: pymongo
#   Building wheel for pymongo (setup.py) ... done
#   Created wheel for pymongo: filename=pymongo-3.7.2-cp38-cp38-linux_x86_64.whl size=415790 sha256=b47d8241e646690943c3b9c93ec9994ca0517d5e83b0c5d80d6bdec67a3fa928
#   Stored in directory: /root/.cache/pip/wheels/28/62/b5/ede9674d1415d2c15c3e805e6cc7debfcdf380105da0887776
# Successfully built pymongo
# Installing collected packages: pymongo
#   Attempting uninstall: pymongo
#     Found existing installation: pymongo 4.3.3
#     Uninstalling pymongo-4.3.3:
#       Successfully uninstalled pymongo-4.3.3
# Successfully installed pymongo-3.7.2

# %%
import datetime                            # Imports datetime library

import pymongo
from pymongo import MongoClient

# uri (uniform resource identifier) defines the connection parameters 
uri = 'mongodb+srv://nbcuser:nbcuser@atlascluster.osjbeup.mongodb.net/?retryWrites=true&w=majority'
# start client to connect to MongoDB server 
client = MongoClient( uri )

# %%
client.list_database_names()
# Out:
# ['News_Articles', 'test', 'admin', 'local']

# %%
db = client.News_Articles

# %% [markdown]
# Following are the names of the tables that are available in the News_Articles's database

# %%
db.list_collection_names()
# Out:
# ['articles', 'categories']

# %%
temp = pd.read_csv(path_dir+'df_w2v.csv')

# %%
import pandas as pd

# %% [markdown]
# Grouping all the articles available in the dataframe according the category of the message.

# %%
techDf=pd.DataFrame()
polDf=pd.DataFrame()
busDf=pd.DataFrame()
sportsDf=pd.DataFrame()
enterDf=pd.DataFrame()

# %%
temp=pd.DataFrame(df_w2v.query('category == "tech"'))
techDf=pd.DataFrame({'heading':"tech",'news':json.loads(temp[['headline','img','category']].to_json(orient='table'))})

temp=pd.DataFrame(df_w2v.query('category == "politics"'))
polDf=pd.DataFrame({'heading':"politics",'news':json.loads(temp[['headline','img','category']].to_json(orient='table'))})

temp=pd.DataFrame(df_w2v.query('category == "sports"'))
busDf=pd.DataFrame({'heading':"sports",'news':json.loads(temp[['headline','img','category']].to_json(orient='table'))})

temp=pd.DataFrame(df_w2v.query('category == "business"'))
sportsDf=pd.DataFrame({'heading':"business",'news':json.loads(temp[['headline','img','category']].to_json(orient='table'))})

temp=pd.DataFrame(df_w2v.query('category == "entertainment"'))
enterDf=pd.DataFrame({'heading':"entertainment",'news':json.loads(temp[['headline','img','category']].to_json(orient='table'))})

# %%
tech=pd.DataFrame(techDf.iloc[0]).T
sports=pd.DataFrame(sportsDf.iloc[0]).T
politics=pd.DataFrame(polDf.iloc[0]).T
entertainment=pd.DataFrame(enterDf.iloc[0]).T
business=pd.DataFrame(busDf.iloc[0]).T

# %% [markdown]
# Pushing the data into the remote MongoDb database named "News_Articles" and the table named "categories". This results in 5 rows in the table with each row standing for a specific category of new article.

# %%
db.categories.insert_one(tech.to_dict())
db.categories.insert_one(sports.to_dict())
db.categories.insert_one(politics.to_dict())
db.categories.insert_one(entertainment.to_dict())
db.categories.insert_one(business.to_dict())

# %%
temp1 = pd.read_csv(path_dir+'temp1.csv')
temp1 = df_w2v.to_dict('records')

# %% [markdown]
# Pushing the data into the remote MongoDb database named "News_Articles" and the table named "articles". This results in articles that are availble in the website on that particular date to be stored into the table with the category and suggestions associated with that particular article included in the table as new columns.

# %%
db.articles.insert_many(temp1.to_dict('records'))

# %% [markdown]
# Hence, the data that is available from the database is fed into the application to make the articles available to the users in summarized form, grouped by the category of the article, and associated with a set of 4 articles recommended to the user after selection of a specific article.
